# %% [markdown]
# # 解析数据的BeautifulSoup模块

# %%
#官方文件：
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/
#https://www.crummy.com/software/BeautifulSoup/bs4/doc.zh/

# %%
'''
Beautiful Soup 是一个可以从HTML或XML文件中提取数据的Python库.
它能够通过你喜欢的转换器实现惯用的文档导航,查找,修改文档的方式.
'''
# Out:
# '\nBeautiful Soup 是一个可以从HTML或XML文件中提取数据的Python库.\n它能够通过你喜欢的转换器实现惯用的文档导航,查找,修改文档的方式.\n'

# %% [markdown]
# ## 9.1使用BeautifulSoup解析数据

# %% [markdown]
# ### 9.1.1 BeautifulSoup的安装

# %%
#pip install beautifulsoup4

# %% [markdown]
# ### 9.1.2 解析器

# %%
'''
推荐使用lxml作为解析器,因为效率更高
'''
# Out:
# '\n推荐使用lxml作为解析器,因为效率更高\n'

# %% [markdown]
# ### 9.1.2 BeautifulSoup的简单运用

# %%
from bs4 import BeautifulSoup  # 导入BeautifulSoup库
import re                      # 导入正则表达式模块

# %%
# 创建模拟HTML代码的字符串
html_doc = """
<html>
<head>
<title>第一个 HTML 页面</title>
</head>
<body>
<p>body 元素的内容会显示在浏览器中。</p>
<p>title 元素的内容会显示在浏览器的标题栏中。</p>
</body>
</html>
"""
# 创建一个BeautifulSoup对象，获取页面正文
soup = BeautifulSoup(html_doc, features="lxml") #指定解析器为lxml
print(soup)                  # 打印解析的HTML代码
print(type(soup))            # 打印数据类型
# Out:
# <html>
# <head>
# <title>第一个 HTML 页面</title>
# </head>
# <body>
# <p>body 元素的内容会显示在浏览器中。</p>
# <p>title 元素的内容会显示在浏览器的标题栏中。</p>
# </body>
# </html>
#
# <class 'bs4.BeautifulSoup'>

# %%
#创建BEautifulSoup对象打开需要解析的HTML文件
soup=BeautifulSoup(open('index.html'),'html5lib')
print(soup.prettify())#打印格式化后的代码
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#  </head>
#  <body>
#   <title1>
#    第一个 HTML 页面
#   </title1>
#   <p>
#    body 元素的内容会显示在浏览器中。
#   </p>
#   <p>
#    title 元素的内容会显示在浏览器的标题栏中。
#   </p>
#  </body>
# </html>

# %% [markdown]
# ## 9.2 获取节点内容

# %% [markdown]
# ### 9.2.1 获取节点对应的代码

# %%
# 创建模拟HTML代码的字符串
html_doc = """
<html>
<head>
<title>第一个 HTML 页面</title>
</head>
<body>
<p>body 元素的内容会显示在浏览器中。</p>
<p>title 元素的内容会显示在浏览器的标题栏中。</p>
</body>
</html>
"""

# 创建一个BeautifulSoup对象，获取页面正文
soup = BeautifulSoup(html_doc, features="lxml")
print('head节点内容为：\n',soup.head)               # 打印head节点
'''
<head>
<title>第一个 HTML 页面</title>
</head>
'''
print('body节点内容为：\n',soup.body)               # 打印body节点
'''
<body>
<p>body 元素的内容会显示在浏览器中。</p>
<p>title 元素的内容会显示在浏览器的标题栏中。</p>
</body>
'''
print('title节点内容为：\n',soup.title)              # 打印title节点
#<title>第一个 HTML 页面</title>
print('p节点内容为：\n',soup.p)                  # 打印p节点
#<p>body 元素的内容会显示在浏览器中。</p>  #只打印了第一个节点，说明多个节点时只会打印第一个节点，可以用loop实现
# Out:
# head节点内容为：
#  <head>
# <title>第一个 HTML 页面</title>
# </head>
# body节点内容为：
#  <body>
# <p>body 元素的内容会显示在浏览器中。</p>
# <p>title 元素的内容会显示在浏览器的标题栏中。</p>
# </body>
# title节点内容为：
#  <title>第一个 HTML 页面</title>
# p节点内容为：
#  <p>body 元素的内容会显示在浏览器中。</p>

# %%
#获取节点名称
print(soup.head.name)
print(soup.body.name)
print(soup.title.name)
print(soup.p.name)
# Out:
# head
# body
# title
# p

# %% [markdown]
# ### 9.2.2 获取节点属性

# %%
'''
Build fast, responsive sites with Bootstrap
Quickly design and customize responsive mobile-first sites with Bootstrap, 
the world’s most popular front-end open source toolkit,
 featuring Sass variables and mixins, responsive grid system,
  extensive prebuilt components, and powerful JavaScript plugins.
'''
# Out:
# '\nBuild fast, responsive sites with Bootstrap\nQuickly design and customize responsive mobile-first sites with Bootstrap, \nthe world’s most popular front-end open source toolkit,\n featuring Sass variables and mixins, responsive grid system,\n  extensive prebuilt components, and powerful JavaScript plugins.\n'

# %%
# 创建模拟HTML代码的字符串
html_doc = """
<html>
<head>
    <title>横排响应式登录</title>
    <meta http-equiv="Content-Type" content="text/html" charset="utf-8"/>
    <meta name="viewport" content="width=device-width"/>
    <link href="font/css/bootstrap.min.css" type="text/css" rel="stylesheet">
    <link href="css/style.css" type="text/css" rel="stylesheet">
</head>
<body>
<h3>登录</h3>
<div class="glyphicon glyphicon-envelope"><input type="text" placeholder="请输入邮箱"></div>
<div class="glyphicon glyphicon-lock"><input type="password" placeholder="请输入密码"></div>
</body>
</html>
"""
# 创建一个BeautifulSoup对象，获取页面正文
soup = BeautifulSoup(html_doc, features="lxml")
print('meta节点中属性如下：\n',soup.meta.attrs)
# {'http-equiv': 'Content-Type', 'content': 'text/html', 'charset': 'utf-8'}
print('link节点中属性如下：\n',soup.link.attrs)
#{'href': 'font/css/bootstrap.min.css', 'type': 'text/css', 'rel': ['stylesheet']}
print('div节点中属性如下：\n',soup.div.attrs)
#{'class': ['glyphicon', 'glyphicon-envelope']}
#type为字典
# Out:
# meta节点中属性如下：
#  {'http-equiv': 'Content-Type', 'content': 'text/html', 'charset': 'utf-8'}
# link节点中属性如下：
#  {'href': 'font/css/bootstrap.min.css', 'type': 'text/css', 'rel': ['stylesheet']}
# div节点中属性如下：
#  {'class': ['glyphicon', 'glyphicon-envelope']}

# %%
print('meta节点中http-equiv属性对应的值为：\n',soup.meta.attrs['http-equiv'])
print('meta节点中http-equiv属性对应的值为：\n',soup.meta['http-equiv'])
# Out:
# meta节点中http-equiv属性对应的值为：
#  Content-Type
# meta节点中http-equiv属性对应的值为：
#  Content-Type

# %% [markdown]
# ### 9.2.3获取节点包含的文本内容

# %%
#获取节点包含的文本内容，节点名称后面添加string属性
print('title节点所包含的文本内容为',soup.title.string)
print('h3节点所包含的文本内容为',soup.h3.string)
# Out:
# title节点所包含的文本内容为 横排响应式登录
# h3节点所包含的文本内容为 登录

# %% [markdown]
# ### 9.2.4 嵌套获取节点内容

# %%
# 创建模拟HTML代码的字符串
html_doc = """
<html>
<head>
    <title>横排响应式登录</title>
    <meta http-equiv="Content-Type" content="text/html" charset="utf-8"/>
    <meta name="viewport" content="width=device-width"/>
    <link href="font/css/bootstrap.min.css" type="text/css" rel="stylesheet">
    <link href="css/style.css" type="text/css" rel="stylesheet">
</head>
</html>
"""
# 创建一个BeautifulSoup对象，获取页面正文
soup = BeautifulSoup(html_doc, features="lxml")
print('head节点内容如下：\n',soup.head)
'''
 <head>
<title>横排响应式登录</title>
<meta charset="utf-8" content="text/html" http-equiv="Content-Type"/>
<meta content="width=device-width" name="viewport"/>
<link href="font/css/bootstrap.min.css" rel="stylesheet" type="text/css"/>
<link href="css/style.css" rel="stylesheet" type="text/css"/>
</head>
'''
print('head节点数据类型为：',type(soup.head))
# <class 'bs4.element.Tag'>
print('head节点中title节点内容如下：\n',soup.head.title)
# <title>横排响应式登录</title>
print('head节点中title节点数据类型为：',type(soup.head.title))
#<class 'bs4.element.Tag'>
print('head节点中title节点中的文本内容为：',soup.head.title.string)
#横排响应式登录
print('head节点中title节点中文本内容的数据类型为：',type(soup.head.title.string))
#<class 'bs4.element.NavigableString'>
# Out:
# head节点内容如下：
#  <head>
# <title>横排响应式登录</title>
# <meta charset="utf-8" content="text/html" http-equiv="Content-Type"/>
# <meta content="width=device-width" name="viewport"/>
# <link href="font/css/bootstrap.min.css" rel="stylesheet" type="text/css"/>
# <link href="css/style.css" rel="stylesheet" type="text/css"/>
# </head>
# head节点数据类型为： <class 'bs4.element.Tag'>
# head节点中title节点内容如下：
#  <title>横排响应式登录</title>
# head节点中title节点数据类型为： <class 'bs4.element.Tag'>
# head节点中title节点中的文本内容为： 横排响应式登录
# head节点中title节点中文本内容的数据类型为： <class 'bs4.element.NavigableString'>

# %% [markdown]
# ### 9.2.5 关联节点

# %% [markdown]
# #### 1.获取子节点 children centents

# %%
#寻找节点为中心对应的子节点，孙节点，父节点以及兄弟节点

# 创建模拟HTML代码的字符串
html_doc = """
<html>
<head>
    <title>关联获取演示</title>
    <meta charset="utf-8"/>
</head>
</html>
"""
# 创建一个BeautifulSoup对象，获取页面正文
soup = BeautifulSoup(html_doc, features="lxml")
print(soup.head.contents)           # 列表形式打印head下所有子节点
print(soup.head.children)           # 可迭代对象形式打印head下所有子节点 list_iterator
# Out:
# ['\n', <title>关联获取演示</title>, '\n', <meta charset="utf-8"/>, '\n']
# <list_iterator object at 0x10f90e970>

# %%
# for loop 遍历节点

print(list(soup.head.children)) #打印将迭代对象转换为列表形式的所有节点

for i in soup.head.children: #循环遍历可迭代对象中的所有子节点
    print(i)
# Out:
# ['\n', <title>关联获取演示</title>, '\n', <meta charset="utf-8"/>, '\n']
#
#
# <title>关联获取演示</title>
#
#
# <meta charset="utf-8"/>

# %% [markdown]
# #### 获取孙节点 defendants

# %%
# 创建模拟HTML代码的字符串
html_doc = """
<html>
…此处省略…
<body>
<div id="test1">
    <div id="test2">
        <ul>
            <li class="test3" value = "user1234">
                此处为演示信息
            </li>
        </ul>
    </div>
</div>
</body>
</html>
"""
# 创建一个BeautifulSoup对象，获取页面正文
soup = BeautifulSoup(html_doc, features="lxml")
print(soup.body.descendants,'打印body节点下所有子孙节点内容的generator对象\n')          # 打印body节点下所有子孙节点内容的generator对象
for i in soup.body.descendants:       # 循环遍历generator对象中的所有子孙节点
    print(i)                            # 打印子孙节点内容
# Out:
# <generator object Tag.descendants at 0x10f92e4a0> 打印body节点下所有子孙节点内容的generator对象
#
# <p>
# …此处省略…
# </p>
#
# …此处省略…
#
#
#
# <div id="test1">
# <div id="test2">
# <ul>
# <li class="test3" value="user1234">
#                 此处为演示信息
#             </li>
# </ul>
# </div>
# </div>
#
#
# <div id="test2">
# <ul>
# <li class="test3" value="user1234">
#                 此处为演示信息
#             </li>
# </ul>
# </div>
#
#
# <ul>
# <li class="test3" value="user1234">
#                 此处为演示信息
#             </li>
# </ul>
#
#
# <li class="test3" value="user1234">
#                 此处为演示信息
#             </li>
#
#                 此处为演示信息

# %% [markdown]
# #### 获取父节点 parents

# %%
# 创建模拟HTML代码的字符串
html_doc = """
<html>
<head>
    <title>关联获取演示</title>
    <meta charset="utf-8"/>
</head>
</html>
"""
# 创建一个BeautifulSoup对象，获取页面正文
soup = BeautifulSoup(html_doc, features="lxml")
print(soup.title.parent,'\n')                # 打印title节点的父节点内容
print(soup.title.parents,'\n')               # 打印title节点的父节点及以上内容的generator对象
for i in soup.title.parents:           # 循环遍历generator对象中的所有父节点及以上内容
    print(i.name)                       # 打印父节点及祖先节点名称
    #[document]表示文档对象，是整个HTML文档，也是BeautifulSoup对象
# Out:
# <head>
# <title>关联获取演示</title>
# <meta charset="utf-8"/>
# </head>
#
# <generator object PageElement.parents at 0x10f929cf0>
#
# head
# html
# [document]

# %% [markdown]
# #### 获取兄弟节点 next_sibling precious_silbing

# %%
# 创建模拟HTML代码的字符串
html_doc = """
<html>
<head>
    <title>关联获取演示</title>
    <meta charset="utf-8"/>
</head>
<body>
<p class="p-1" value = "1"><a href="https://item.jd.com/12353915.html">零基础学Python</a></p>
第一个p节点下文本
<div class="div-1" value = "2"><a href="https://item.jd.com/12451724.html">Python从入门到项目实践</a></div>
<p class="p-3" value = "3"><a href="https://item.jd.com/12512461.html">Python项目开发案例集锦</a></p>
<div class="div-2" value = "4"><a href="https://item.jd.com/12550531.html">Python编程锦囊</a></div>
</body>
</html>
"""
# 创建一个BeautifulSoup对象，获取页面正文
soup = BeautifulSoup(html_doc, features="lxml")
print(soup.p.next_sibling)               # 打印第一个p节点下一个兄弟节点（文本节点内容）
#第一个p节点下文本
print(list(soup.p.next_sibling))         # 以列表形式打印文本节点中的所有元素
div = soup.p.next_sibling.next_sibling  # 获取p节点同级的第一个div节点
print(div)                               # 打印第一个div节点内容
print(div.previous_sibling)              # 打印第一个div节点上一个兄弟节点（文本节点内容）
# Out:
# 第一个p节点下文本
#
# ['\n', '第', '一', '个', 'p', '节', '点', '下', '文', '本', '\n']
# <div class="div-1" value="2"><a href="https://item.jd.com/12451724.html">Python从入门到项目实践</a></div>
#
# 第一个p节点下文本

# %%
print('获取p节点后面所有兄弟节点如下： \n',list(soup.p.next_siblings))
print('获取p节点前面所有兄弟节点如下： \n',list(soup.p.previous_siblings))
# Out:
# 获取p节点后面所有兄弟节点如下：
#  ['\n第一个p节点下文本\n', <div class="div-1" value="2"><a href="https://item.jd.com/12451724.html">Python从入门到项目实践</a></div>, '\n', <p class="p-3" value="3"><a href="https://item.jd.com/12512461.html">Python项目开发案例集锦</a></p>, '\n', <div class="div-2" value="4"><a href="https://item.jd.com/12550531.html">Python编程锦囊</a></div>, '\n']
# 获取p节点前面所有兄弟节点如下：
#  ['\n']

# %% [markdown]
# ## 9.3 方法获取内容

# %% [markdown]
# ### 9.3.1 find_all() 获取所有符合条件的内容

# %% [markdown]
# #### 1.name参数

# %%
# 创建模拟HTML代码的字符串
html_doc = """
<html>
<head>
    <title>关联获取演示</title>
    <meta charset="utf-8"/>
</head>

<body>
<p class="p-1" value = "1"><a href="https://item.jd.com/12353915.html">零基础学Python</a></p>
<p class="p-2" value = "2"><a href="https://item.jd.com/12451724.html">Python从入门到项目实践</a></p>
<p class="p-3" value = "3"><a href="https://item.jd.com/12512461.html">Python项目开发案例集锦</a></p>
<div class="div-2" value = "4"><a href="https://item.jd.com/12550531.html">Python编程锦囊</a></div>
</body>
</html>
"""
# 创建一个BeautifulSoup对象，获取页面正文
soup = BeautifulSoup(html_doc, features="lxml")
print(soup.find_all(name='p'))           # 打印名称为p的所有节点内容
print(type(soup.find_all(name='p')))     # 打印数据类型
# Out:
# [<p class="p-1" value="1"><a href="https://item.jd.com/12353915.html">零基础学Python</a></p>, <p class="p-2" value="2"><a href="https://item.jd.com/12451724.html">Python从入门到项目实践</a></p>, <p class="p-3" value="3"><a href="https://item.jd.com/12512461.html">Python项目开发案例集锦</a></p>]
# <class 'bs4.element.ResultSet'>

# %%
print(type(soup.find_all(name='p')[0]))
print(soup.find_all(name='p')[0])
print(soup.find_all(name='p')[0].find_all(name='a'))
# Out:
# <class 'bs4.element.Tag'>
# <p class="p-1" value="1"><a href="https://item.jd.com/12353915.html">零基础学Python</a></p>
# [<a href="https://item.jd.com/12353915.html">零基础学Python</a>]

# %% [markdown]
# #### 2.attrs参数

# %%
# 创建模拟HTML代码的字符串
html_doc = """
<html>
<head>
    <title>关联获取演示</title>
    <meta charset="utf-8"/>
</head>
<body>
<p class="p-1" value = "1"><a href="https://item.jd.com/12353915.html">零基础学Python</a></p>
<p class="p-1" value = "2"><a href="https://item.jd.com/12451724.html">Python从入门到项目实践</a></p>
<p class="p-3" value = "3"><a href="https://item.jd.com/12512461.html">Python项目开发案例集锦</a></p>
<div class="div-2" value = "4"><a href="https://item.jd.com/12550531.html">Python编程锦囊</a></div>
</body>
</html>
"""
# 创建一个BeautifulSoup对象，获取页面正文
soup = BeautifulSoup(html_doc, features="lxml")
print('字典参数结果如下：')
print(soup.find_all(attrs={'value':'1'}))        # 打印value值为1的所有内容，字典参数
print('赋值参数结果如下：')
print(soup.find_all(class_='p-1'))               # 打印class为p-1的所有内容，赋值参数
print(soup.find_all(value='3'))                  # 打印value值为3的所有内容，赋值参数
# Out:
# 字典参数结果如下：
# [<p class="p-1" value="1"><a href="https://item.jd.com/12353915.html">零基础学Python</a></p>]
# 赋值参数结果如下：
# [<p class="p-1" value="1"><a href="https://item.jd.com/12353915.html">零基础学Python</a></p>, <p class="p-1" value="2"><a href="https://item.jd.com/12451724.html">Python从入门到项目实践</a></p>]
# [<p class="p-3" value="3"><a href="https://item.jd.com/12512461.html">Python项目开发案例集锦</a></p>]

# %% [markdown]
# #### 3.text参数

# %%
# 创建模拟HTML代码的字符串
html_doc = """
<html>
<head>
    <title>关联获取演示</title>
    <meta charset="utf-8"/>
</head>
<body>
<p class="p-1" value = "1"><a href="https://item.jd.com/12353915.html">零基础学Python</a></p>
<p class="p-1" value = "2"><a href="https://item.jd.com/12451724.html">Python从入门到项目实践</a></p>
<p class="p-3" value = "3"><a href="https://item.jd.com/12512461.html">Python项目开发案例集锦</a></p>
<div class="div-2" value = "4"><a href="https://item.jd.com/12550531.html">Python编程锦囊</a></div>
</body>
</html>
"""
# 创建一个BeautifulSoup对象，获取页面正文
soup = BeautifulSoup(html_doc, features="lxml")
print('指定字符串所获取的内容如下：')
print(soup.find_all(text='零基础学Python'))         # 打印指定字符串所获取的内容
print('指定正则表达式对象所获取的内容如下：')
print(soup.find_all(text=re.compile('Python')))    # 打印指定正则表达式对象所获取的内容
# Out:
# 指定字符串所获取的内容如下：
# ['零基础学Python']
# 指定正则表达式对象所获取的内容如下：
# ['零基础学Python', 'Python从入门到项目实践', 'Python项目开发案例集锦', 'Python编程锦囊']

# %% [markdown]
# ### 9.2.3 find()获取第一个匹配的节点内容

# %%
# 创建模拟HTML代码的字符串
html_doc = """
<html>
<head>
    <title>关联获取演示</title>
    <meta charset="utf-8"/>
</head>
<body>
<p class="p-1" value = "1"><a href="https://item.jd.com/12353915.html">零基础学Python</a></p>
<p class="p-1" value = "2"><a href="https://item.jd.com/12451724.html">Python从入门到项目实践</a></p>
<p class="p-3" value = "3"><a href="https://item.jd.com/12512461.html">Python项目开发案例集锦</a></p>
<div class="div-2" value = "4"><a href="https://item.jd.com/12550531.html">Python编程锦囊</a></div>
</body>
</html>
"""
# 创建一个BeautifulSoup对象，获取页面正文
soup = BeautifulSoup(html_doc, features="lxml")
print(soup.find(name='p'))                  # 打印第一个name为p的节点内容
print(soup.find(class_='p-3'))              # 打印第一个class为p-3的节点内容
print(soup.find(attrs={'value':'4'}))       # 打印第一个value为4的节点内容
print(soup.find(text=re.compile('Python'))) # 打印第一个文本中包含Python的文本信息
# Out:
# <p class="p-1" value="1"><a href="https://item.jd.com/12353915.html">零基础学Python</a></p>
# <p class="p-3" value="3"><a href="https://item.jd.com/12512461.html">Python项目开发案例集锦</a></p>
# <div class="div-2" value="4"><a href="https://item.jd.com/12550531.html">Python编程锦囊</a></div>
# 零基础学Python

# %% [markdown]
# ## 9.3 CSS选择器

# %%
#https://www.w3schools.com/cssref/css_selectors.asp
#In CSS, selectors are patterns used to select the element(s) you want to style.
# https://www.w3school.com.cn/cssref/css_selectors.ASP
#CSS是Cascading Style Sheets的简称，中文称为层叠样式表，对html标签的渲染和布局
#CSS 规则由两个主要的部分构成：选择器，以及一条或多条声明。

# %%
# 创建模拟HTML代码的字符串
html_doc = """
<html>
<head>
    <title>关联获取演示</title>
    <meta charset="utf-8"/>
</head>
<body>
    <div class="test_1" id="class_1"> 
        <p class="p-1" value = "1"><a href="https://item.jd.com/12353915.html">零基础学Python</a></p>
        <p class="p-2" value = "2"><a href="https://item.jd.com/12451724.html">Python从入门到项目实践</a></p>
        <p class="p-3" value = "3"><a href="https://item.jd.com/12512461.html">Python项目开发案例集锦</a></p>
        <p class="p-4" value = "4"><a href="https://item.jd.com/12550531.html">Python编程锦囊</a></p>
    </div>
    <div class="test_2" id="class_2">
        <p class="p-5"><a href="https://item.jd.com/12185501.html">零基础学Java（全彩版）</a></p>
        <p class="p-6"><a href="https://item.jd.com/12199033.html">零基础学Android（全彩版）</a></p>
        <p class="p-7"><a href="https://item.jd.com/12250414.html">零基础学C语言（全彩版）</a></p>
    </div>    
</body>
</html>
"""
# 创建一个BeautifulSoup对象，获取页面正文
soup = BeautifulSoup(html_doc, features="lxml")
print(soup.select('p'))                # 打印所有p节点内容
print('所有p节点内容如下：')
'''
[<p class="p-1" value="1"><a href="https://item.jd.com/12353915.html">零基础学Python</a></p>, 
<p class="p-2" value="2"><a href="https://item.jd.com/12451724.html">Python从入门到项目实践</a></p>, 
<p class="p-3" value="3"><a href="https://item.jd.com/12512461.html">Python项目开发案例集锦</a></p>, 
<p class="p-4" value="4"><a href="https://item.jd.com/12550531.html">Python编程锦囊</a></p>, 
<p class="p-5"><a href="https://item.jd.com/12185501.html">零基础学Java（全彩版）</a></p>, 
<p class="p-6"><a href="https://item.jd.com/12199033.html">零基础学Android（全彩版）</a></p>, 
<p class="p-7"><a href="https://item.jd.com/12250414.html">零基础学C语言（全彩版）</a></p>]
'''
print('所有p节点中的第二个p节点内容如下：')
print(soup.select('p')[1])             # 打印所有p节点中的第二个p节点
#<p class="p-2" value="2"><a href="https://item.jd.com/12451724.html">Python从入门到项目实践</a></p>
print('逐层获取的title节点如下：')
print(soup.select('html head title'))  # 打印逐层获取的title节点
#[<title>关联获取演示</title>]
print('类名为test_2所对应的节点如下：')
print(soup.select('.test_2'))          # 打印类名为test_2所对应的节点
'''
[<div class="test_2" id="class_2">
<p class="p-5"><a href="https://item.jd.com/12185501.html">零基础学Java（全彩版）</a></p>
<p class="p-6"><a href="https://item.jd.com/12199033.html">零基础学Android（全彩版）</a></p>
<p class="p-7"><a href="https://item.jd.com/12250414.html">零基础学C语言（全彩版）</a></p>
</div>]
'''
print('id值为class_1所对应的节点如下：')
print(soup.select('#class_1'))         # 打印id值为class_1所对应的节点
'''
[<div class="test_1" id="class_1">
<p class="p-1" value="1"><a href="https://item.jd.com/12353915.html">零基础学Python</a></p>
<p class="p-2" value="2"><a href="https://item.jd.com/12451724.html">Python从入门到项目实践</a></p>
<p class="p-3" value="3"><a href="https://item.jd.com/12512461.html">Python项目开发案例集锦</a></p>
<p class="p-4" value="4"><a href="https://item.jd.com/12550531.html">Python编程锦囊</a></p>
</div>]
'''
print(soup.select_one('a'))         # 打印a节点的第一个内容
#<a href="https://item.jd.com/12353915.html">零基础学Python</a>
# Out:
# [<p class="p-1" value="1"><a href="https://item.jd.com/12353915.html">零基础学Python</a></p>, <p class="p-2" value="2"><a href="https://item.jd.com/12451724.html">Python从入门到项目实践</a></p>, <p class="p-3" value="3"><a href="https://item.jd.com/12512461.html">Python项目开发案例集锦</a></p>, <p class="p-4" value="4"><a href="https://item.jd.com/12550531.html">Python编程锦囊</a></p>, <p class="p-5"><a href="https://item.jd.com/12185501.html">零基础学Java（全彩版）</a></p>, <p class="p-6"><a href="https://item.jd.com/12199033.html">零基础学Android（全彩版）</a></p>, <p class="p-7"><a href="https://item.jd.com/12250414.html">零基础学C语言（全彩版）</a></p>]
# 所有p节点内容如下：
# 所有p节点中的第二个p节点内容如下：
# <p class="p-2" value="2"><a href="https://item.jd.com/12451724.html">Python从入门到项目实践</a></p>
# 逐层获取的title节点如下：
# [<title>关联获取演示</title>]
# 类名为test_2所对应的节点如下：
# [<div class="test_2" id="class_2">
# <p class="p-5"><a href="https://item.jd.com/12185501.html">零基础学Java（全彩版）</a></p>
# <p class="p-6"><a href="https://item.jd.com/12199033.html">零基础学Android（全彩版）</a></p>
# <p class="p-7"><a href="https://item.jd.com/12250414.html">零基础学C语言（全彩版）</a></p>
# </div>]
# id值为class_1所对应的节点如下：
# [<div class="test_1" id="class_1">
# <p class="p-1" value="1"><a href="https://item.jd.com/12353915.html">零基础学Python</a></p>
# <p class="p-2" value="2"><a href="https://item.jd.com/12451724.html">Python从入门到项目实践</a></p>
# <p class="p-3" value="3"><a href="https://item.jd.com/12512461.html">Python项目开发案例集锦</a></p>
# <p class="p-4" value="4"><a href="https://item.jd.com/12550531.html">Python编程锦囊</a></p>
# </div>]
# <a href="https://item.jd.com/12353915.html">零基础学Python</a>

# %% [markdown]
# ## test

# %%
import time               # 导入时间模块
import random             # 导入随机模块
import requests           # 导入网络请求模块
header = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.61 Safari/537.36'}
# 处理字符串中的空白符，并拼接字符串
def processing(strs):
    s = ''  # 定义保存内容的字符串
    for n in strs:
        n = ''.join(n.split())  # 去除空字符
        s = s + n  # 拼接字符串
    return s      # 返回拼接后的字符串

# 获取电影信息
def get_movie_info(url):
    response = requests.get(url,headers=header)                    # 发送网络请求
    soup = BeautifulSoup(response.text, "lxml")
    #html = etree.HTML(response.text)                               # 解析html字符串
    div_all = soup.find_all('div', class_='info')
    #div_all = html.xpath('//div[@class="info"]')
    for div in div_all:
        names = div.find('div', class_='hd').a.span.text   # 获取电影名字相关信息
        name = processing(names)                                    # 处理电影名称信息
        infos = div.find('div', class_='bd').p.text         # 获取导演、主演等信息
        info = processing(infos)                                   # 处理导演、主演等信息
        score = div.find('span', class_='rating_num').text     # 获取电影评分
        evaluation = div.find('div', class_='star').contents[7].text # 获取评价人数
        # 获取电影总结文字
        try:
            summary = div.find('span', class_='inq').text
        except:
            summary=''
        print('电影名称：',name)
        print('导演与演员：',info)
        print('电影评分：',score)
        print('评价人数：',evaluation)
        print('电影总结：',summary)
        print('--------分隔线--------')
if __name__ == '__main__':
    for i in range(0,250,25):    # 每页25为间隔，实现循环，共10页
        # 通过format替换切换页码的url地址
        url = 'https://movie.douban.com/top250?start={page}&filter='.format(page=i)
        get_movie_info(url)                      # 调用爬虫方法,获取电影信息
        time.sleep(random.randint(1,3))          # 等待1至3秒随机时间
# Out:
# 电影名称： 肖申克的救赎
# 导演与演员： 导演:弗兰克·德拉邦特FrankDarabont主演:蒂姆·罗宾斯TimRobbins/...1994/美国/犯罪剧情
# 电影评分： 9.7
# 评价人数： 2480275人评价
# 电影总结： 希望让人自由。
# --------分隔线--------
# 电影名称： 霸王别姬
# 导演与演员： 导演:陈凯歌KaigeChen主演:张国荣LeslieCheung/张丰毅FengyiZha...1993/中国大陆中国香港/剧情爱情同性
# 电影评分： 9.6
# 评价人数： 1843753人评价
# 电影总结： 风华绝代。
# --------分隔线--------
# 电影名称： 阿甘正传
# 导演与演员： 导演:罗伯特·泽米吉斯RobertZemeckis主演:汤姆·汉克斯TomHanks/...1994/美国/剧情爱情
# 电影评分： 9.5
# 评价人数： 1863841人评价
# 电影总结： 一部美国近现代史。
# --------分隔线--------
# 电影名称： 这个杀手不太冷
# 导演与演员： 导演:吕克·贝松LucBesson主演:让·雷诺JeanReno/娜塔莉·波特曼...1994/法国美国/剧情动作犯罪
# 电影评分： 9.4
# 评价人数： 2027038人评价
# 电影总结： 怪蜀黍和小萝莉不得不说的故事。
# --------分隔线--------
# 电影名称： 泰坦尼克号
# 导演与演员： 导演:詹姆斯·卡梅隆JamesCameron主演:莱昂纳多·迪卡普里奥Leonardo...1997/美国墨西哥澳大利亚加拿大/剧情爱情灾难
# 电影评分： 9.4
# 评价人数： 1825593人评价
# 电影总结： 失去的才是永恒的。
# --------分隔线--------
# 电影名称： 美丽人生
# 导演与演员： 导演:罗伯托·贝尼尼RobertoBenigni主演:罗伯托·贝尼尼RobertoBeni...1997/意大利/剧情喜剧爱情战争
# 电影评分： 9.6
# 评价人数： 1142598人评价
# 电影总结： 最美的谎言。
# --------分隔线--------
# 电影名称： 千与千寻
# 导演与演员： 导演:宫崎骏HayaoMiyazaki主演:柊瑠美RumiHîragi/入野自由Miy...2001/日本/剧情动画奇幻
# 电影评分： 9.4
# 评价人数： 1944720人评价
# 电影总结： 最好的宫崎骏，最好的久石让。
# --------分隔线--------
# 电影名称： 辛德勒的名单
# 导演与演员： 导演:史蒂文·斯皮尔伯格StevenSpielberg主演:连姆·尼森LiamNeeson...1993/美国/剧情历史战争
# 电影评分： 9.5
# 评价人数： 952710人评价
# 电影总结： 拯救一个人，就是拯救整个世界。
# --------分隔线--------
# 电影名称： 盗梦空间
# 导演与演员： 导演:克里斯托弗·诺兰ChristopherNolan主演:莱昂纳多·迪卡普里奥Le...2010/美国英国/剧情科幻悬疑冒险
# 电影评分： 9.3
# 评价人数： 1791459人评价
# 电影总结： 诺兰给了我们一场无法盗取的梦。
# --------分隔线--------
# 电影名称： 忠犬八公的故事
# 导演与演员： 导演:莱塞·霍尔斯道姆LasseHallström主演:理查·基尔RichardGer...2009/美国英国/剧情
# 电影评分： 9.4
# 评价人数： 1230576人评价
# 电影总结： 永远都不能忘记你所爱的人。
# --------分隔线--------
# 电影名称： 星际穿越
# 导演与演员： 导演:克里斯托弗·诺兰ChristopherNolan主演:马修·麦康纳MatthewMc...2014/美国英国加拿大/剧情科幻冒险
# 电影评分： 9.3
# 评价人数： 1468574人评价
# 电影总结： 爱是一种力量，让我们超越时空感知它的存在。
# --------分隔线--------
# 电影名称： 楚门的世界
# 导演与演员： 导演:彼得·威尔PeterWeir主演:金·凯瑞JimCarrey/劳拉·琳妮Lau...1998/美国/剧情科幻
# 电影评分： 9.3
# 评价人数： 1390813人评价
# 电影总结： 如果再也不能见到你，祝你早安，午安，晚安。
# --------分隔线--------
# 电影名称： 海上钢琴师
# 导演与演员： 导演:朱塞佩·托纳多雷GiuseppeTornatore主演:蒂姆·罗斯TimRoth/...1998/意大利/剧情音乐
# 电影评分： 9.3
# 评价人数： 1455844人评价
# 电影总结： 每个人都要走一条自己坚定了的路，就算是粉身碎骨。
# --------分隔线--------
# 电影名称： 三傻大闹宝莱坞
# 导演与演员： 导演:拉库马·希拉尼RajkumarHirani主演:阿米尔·汗AamirKhan/卡...2009/印度/剧情喜剧爱情歌舞
# 电影评分： 9.2
# 评价人数： 1630631人评价
# 电影总结： 英俊版憨豆，高情商版谢耳朵。
# --------分隔线--------
# 电影名称： 机器人总动员
# 导演与演员： 导演:安德鲁·斯坦顿AndrewStanton主演:本·贝尔特BenBurtt/艾丽...2008/美国/科幻动画冒险
# 电影评分： 9.3
# 评价人数： 1148319人评价
# 电影总结： 小瓦力，大人生。
# --------分隔线--------
# 电影名称： 放牛班的春天
# 导演与演员： 导演:克里斯托夫·巴拉蒂ChristopheBarratier主演:热拉尔·朱尼奥Gé...2004/法国瑞士德国/剧情喜剧音乐
# 电影评分： 9.3
# 评价人数： 1133274人评价
# 电影总结： 天籁一般的童声，是最接近上帝的存在。
# --------分隔线--------
# 电影名称： 无间道
# 导演与演员： 导演:刘伟强/麦兆辉主演:刘德华/梁朝伟/黄秋生2002/中国香港/剧情犯罪惊悚
# 电影评分： 9.3
# 评价人数： 1125353人评价
# 电影总结： 香港电影史上永不过时的杰作。
# --------分隔线--------
# 电影名称： 疯狂动物城
# 导演与演员： 导演:拜伦·霍华德ByronHoward/瑞奇·摩尔RichMoore主演:金妮弗·...2016/美国/喜剧动画冒险
# 电影评分： 9.2
# 评价人数： 1620543人评价
# 电影总结： 迪士尼给我们营造的乌托邦就是这样，永远善良勇敢，永远出乎意料。
# --------分隔线--------
# 电影名称： 大话西游之大圣娶亲
# 导演与演员： 导演:刘镇伟JeffreyLau主演:周星驰StephenChow/吴孟达ManTatNg...1995/中国香港中国大陆/喜剧爱情奇幻古装
# 电影评分： 9.2
# 评价人数： 1327649人评价
# 电影总结： 一生所爱。
# --------分隔线--------
# 电影名称： 熔炉
# 导演与演员： 导演:黄东赫Dong-hyukHwang主演:孔侑YooGong/郑有美Yu-miJung/...2011/韩国/剧情
# 电影评分： 9.3
# 评价人数： 806661人评价
# 电影总结： 我们一路奋战不是为了改变世界，而是为了不让世界改变我们。
# --------分隔线--------
# 电影名称： 教父
# 导演与演员： 导演:弗朗西斯·福特·科波拉FrancisFordCoppola主演:马龙·白兰度M...1972/美国/剧情犯罪
# 电影评分： 9.3
# 评价人数： 811509人评价
# 电影总结： 千万不要记恨你的对手，这样会让你失去理智。
# --------分隔线--------
# 电影名称： 当幸福来敲门
# 导演与演员： 导演:加布里尔·穆奇诺GabrieleMuccino主演:威尔·史密斯WillSmith...2006/美国/剧情传记家庭
# 电影评分： 9.1
# 评价人数： 1315735人评价
# 电影总结： 平民励志片。
# --------分隔线--------
# 电影名称： 龙猫
# 导演与演员： 导演:宫崎骏HayaoMiyazaki主演:日高法子NorikoHidaka/坂本千夏Ch...1988/日本/动画奇幻冒险
# 电影评分： 9.2
# 评价人数： 1098888人评价
# 电影总结： 人人心中都有个龙猫，童年就永远不会消失。
# --------分隔线--------
# 电影名称： 控方证人
# 导演与演员： 导演:比利·怀尔德BillyWilder主演:泰隆·鲍华TyronePower/玛琳·...1957/美国/剧情犯罪悬疑
# 电影评分： 9.6
# 评价人数： 404464人评价
# 电影总结： 比利·怀德满分作品。
# --------分隔线--------
# 电影名称： 怦然心动
# 导演与演员： 导演:罗伯·莱纳RobReiner主演:玛德琳·卡罗尔MadelineCarroll/卡...2010/美国/剧情喜剧爱情
# 电影评分： 9.1
# 评价人数： 1571515人评价
# 电影总结： 真正的幸福是来自内心深处。
# --------分隔线--------
# 电影名称： 触不可及
# 导演与演员： 导演:奥利维·那卡什OlivierNakache/艾力克·托兰达EricToledano主...2011/法国/剧情喜剧
# 电影评分： 9.3
# 评价人数： 885448人评价
# 电影总结： 满满温情的高雅喜剧。
# --------分隔线--------
# 电影名称： 末代皇帝
# 导演与演员： 导演:贝纳尔多·贝托鲁奇BernardoBertolucci主演:尊龙JohnLone/陈...1987/英国意大利中国大陆法国/剧情传记历史
# 电影评分： 9.3
# 评价人数： 715942人评价
# 电影总结： “不要跟我比惨，我比你更惨”再适合这部电影不过了。
# --------分隔线--------
# 电影名称： 蝙蝠侠：黑暗骑士
# 导演与演员： 导演:克里斯托弗·诺兰ChristopherNolan主演:克里斯蒂安·贝尔Christ...2008/美国英国/剧情动作科幻犯罪惊悚
# 电影评分： 9.2
# 评价人数： 901352人评价
# 电影总结： 无尽的黑暗。
# --------分隔线--------
# 电影名称： 寻梦环游记
# 导演与演员： 导演:李·昂克里奇LeeUnkrich/阿德里安·莫利纳AdrianMolina主演:...2017/美国/喜剧动画奇幻音乐
# 电影评分： 9.1
# 评价人数： 1386015人评价
# 电影总结： 死亡不是真的逝去，遗忘才是永恒的消亡。
# --------分隔线--------
# 电影名称： 活着
# 导演与演员： 导演:张艺谋YimouZhang主演:葛优YouGe/巩俐LiGong/姜武WuJiang1994/中国大陆中国香港/剧情历史家庭
# 电影评分： 9.3
# 评价人数： 702388人评价
# 电影总结： 张艺谋最好的电影。
# --------分隔线--------
# 电影名称： 指环王3：王者无敌
# 导演与演员： 导演:彼得·杰克逊PeterJackson主演:伊利亚·伍德ElijahWood/西恩...2003/美国新西兰/剧情动作奇幻冒险
# 电影评分： 9.3
# 评价人数： 687780人评价
# 电影总结： 史诗的终章。
# --------分隔线--------
# 电影名称： 哈利·波特与魔法石
# 导演与演员： 导演:ChrisColumbus主演:DanielRadcliffe/EmmaWatson/RupertGrint2001/美国英国/奇幻冒险
# 电影评分： 9.1
# 评价人数： 959415人评价
# 电影总结： 童话世界的开端。
# --------分隔线--------
# 电影名称： 乱世佳人
# 导演与演员： 导演:维克多·弗莱明VictorFleming/乔治·库克GeorgeCukor主演:费...1939/美国/剧情历史爱情战争
# 电影评分： 9.3
# 评价人数： 594891人评价
# 电影总结： Tomorrow is another day.
# --------分隔线--------
# 电影名称： 何以为家
# 导演与演员： 导演:娜丁·拉巴基NadineLabaki主演:扎因·拉费阿Zainal-Rafeea/...2018/黎巴嫩美国法国塞浦路斯卡塔尔英国/剧情
# 电影评分： 9.1
# 评价人数： 880802人评价
# 电影总结： 凝视卑弱生命，用电影改变命运。
# --------分隔线--------
# 电影名称： 素媛
# 导演与演员： 导演:李濬益Jun-ikLee主演:薛景求Kyung-guSol/严志媛Ji-wonUhm...2013/韩国/剧情
# 电影评分： 9.3
# 评价人数： 577016人评价
# 电影总结： 受过伤害的人总是笑得最开心，因为他们不愿意让身边的人承受一样的痛苦。
# --------分隔线--------
# 电影名称： 飞屋环游记
# 导演与演员： 导演:彼特·道格特PeteDocter/鲍勃·彼德森BobPeterson主演:爱德...2009/美国/剧情喜剧动画冒险
# 电影评分： 9.1
# 评价人数： 1146299人评价
# 电影总结： 最后那些最无聊的事情，才是最值得怀念的。
# --------分隔线--------
# 电影名称： 摔跤吧！爸爸
# 导演与演员： 导演:涅提·蒂瓦里NiteshTiwari主演:阿米尔·汗AamirKhan/法缇玛...2016/印度/剧情传记运动家庭
# 电影评分： 9.0
# 评价人数： 1359803人评价
# 电影总结： 你不是在为你一个人战斗，你要让千千万万的女性看到女生并不是只能相夫教子。
# --------分隔线--------
# 电影名称： 十二怒汉
# 导演与演员： 导演:SidneyLumet主演:亨利·方达HenryFonda/马丁·鲍尔萨姆Marti...1957/美国/剧情
# 电影评分： 9.4
# 评价人数： 401957人评价
# 电影总结： 1957年的理想主义。
# --------分隔线--------
# 电影名称： 哈尔的移动城堡
# 导演与演员： 导演:宫崎骏HayaoMiyazaki主演:倍赏千惠子ChiekoBaishô/木村拓...2004/日本/动画奇幻冒险
# 电影评分： 9.1
# 评价人数： 861648人评价
# 电影总结： 带着心爱的人在天空飞翔。
# --------分隔线--------
# 电影名称： 我不是药神
# 导演与演员： 导演:文牧野MuyeWen主演:徐峥ZhengXu/王传君ChuanjunWang/周...2018/中国大陆/剧情喜剧
# 电影评分： 9.0
# 评价人数： 1808952人评价
# 电影总结： 对我们国家而言，这样的电影多一部是一部。
# --------分隔线--------
# 电影名称： 少年派的奇幻漂流
# 导演与演员： 导演:李安AngLee主演:苏拉·沙玛SurajSharma/伊尔凡·可汗Irrfan...2012/美国中国台湾英国加拿大/剧情奇幻冒险
# 电影评分： 9.1
# 评价人数： 1188720人评价
# 电影总结： 瑰丽壮观、无人能及的冒险之旅。
# --------分隔线--------
# 电影名称： 鬼子来了
# 导演与演员： 导演:姜文WenJiang主演:姜文WenJiang/香川照之TeruyukiKagawa/...2000/中国大陆/剧情喜剧
# 电影评分： 9.3
# 评价人数： 532087人评价
# 电影总结： 对敌人的仁慈，就是对自己残忍。
# --------分隔线--------
# 电影名称： 大话西游之月光宝盒
# 导演与演员： 导演:刘镇伟JeffreyLau主演:周星驰StephenChow/吴孟达ManTatNg...1995/中国香港中国大陆/喜剧爱情奇幻古装
# 电影评分： 9.0
# 评价人数： 1057991人评价
# 电影总结： 旷古烁今。
# --------分隔线--------
# 电影名称： 天空之城
# 导演与演员： 导演:宫崎骏HayaoMiyazaki主演:田中真弓MayumiTanaka/横泽启子Ke...1986/日本/动画奇幻冒险
# 电影评分： 9.1
# 评价人数： 716505人评价
# 电影总结： 对天空的追逐，永不停止。
# --------分隔线--------
# 电影名称： 天堂电影院
# 导演与演员： 导演:朱塞佩·托纳多雷GiuseppeTornatore主演:菲利普·努瓦雷Philipp...1988/意大利法国/剧情爱情
# 电影评分： 9.2
# 评价人数： 591663人评价
# 电影总结： 那些吻戏，那些青春，都在影院的黑暗里被泪水冲刷得无比清晰。
# --------分隔线--------
# 电影名称： 猫鼠游戏
# 导演与演员： 导演:史蒂文·斯皮尔伯格StevenSpielberg主演:莱昂纳多·迪卡普里奥L...2002/美国加拿大/传记犯罪剧情
# 电影评分： 9.1
# 评价人数： 797147人评价
# 电影总结： 骗子大师和执著警探的你追我跑故事。
# --------分隔线--------
# 电影名称： 闻香识女人
# 导演与演员： 导演:马丁·布莱斯MartinBrest主演:阿尔·帕西诺AlPacino/克里斯...1992/美国/剧情
# 电影评分： 9.1
# 评价人数： 742977人评价
# 电影总结： 史上最美的探戈。
# --------分隔线--------
# 电影名称： 指环王2：双塔奇兵
# 导演与演员： 导演:彼得·杰克逊PeterJackson主演:伊利亚·伍德ElijahWood/西恩...2002/美国新西兰/剧情动作奇幻冒险
# 电影评分： 9.2
# 评价人数： 641239人评价
# 电影总结： 承前启后的史诗篇章。
# --------分隔线--------
# 电影名称： 罗马假日
# 导演与演员： 导演:威廉·惠勒WilliamWyler主演:奥黛丽·赫本AudreyHepburn/格...1953/美国/喜剧剧情爱情
# 电影评分： 9.1
# 评价人数： 833911人评价
# 电影总结： 爱情哪怕只有一天。
# --------分隔线--------
# 电影名称： 钢琴家
# 导演与演员： 导演:罗曼·波兰斯基RomanPolanski主演:艾德里安·布洛迪AdrienBrod...2002/英国法国波兰德国/剧情传记战争音乐
# 电影评分： 9.2
# 评价人数： 492130人评价
# 电影总结： 音乐能化解仇恨。
# --------分隔线--------
# 电影名称： 指环王1：护戒使者
# 导演与演员： 导演:彼得·杰克逊PeterJackson主演:伊利亚·伍德ElijahWood/西恩...2001/新西兰美国/剧情动作奇幻冒险
# 电影评分： 9.1
# 评价人数： 727480人评价
# 电影总结： 传说的开始。
# --------分隔线--------
# 电影名称： 让子弹飞
# 导演与演员： 导演:姜文WenJiang主演:姜文WenJiang/葛优YouGe/周润发Yun-F...2010/中国大陆中国香港/剧情喜剧动作西部
# 电影评分： 8.9
# 评价人数： 1420732人评价
# 电影总结： 你给我翻译翻译，神马叫做TMD的惊喜。
# --------分隔线--------
# 电影名称： 辩护人
# 导演与演员： 导演:杨宇硕Woo-seokYang主演:宋康昊Kang-hoSong/金英爱Yeong-ae...2013/韩国/剧情
# 电影评分： 9.2
# 评价人数： 517295人评价
# 电影总结： 电影的现实意义大过电影本身。
# --------分隔线--------
# 电影名称： 大闹天宫
# 导演与演员： 导演:万籁鸣LaimingWan主演:邱岳峰YuefengQiu/富润生RunshengFu...1961(中国大陆)/1964(中国大陆)/1978(中国大陆)/中国大陆/剧情动画奇幻古装
# 电影评分： 9.4
# 评价人数： 360596人评价
# 电影总结： 经典之作，历久弥新。
# --------分隔线--------
# 电影名称： 教父2
# 导演与演员： 导演:弗朗西斯·福特·科波拉FrancisFordCoppola主演:阿尔·帕西诺A...1974/美国/剧情犯罪
# 电影评分： 9.2
# 评价人数： 457268人评价
# 电影总结： 优雅的孤独。
# --------分隔线--------
# 电影名称： 狮子王
# 导演与演员： 导演:RogerAllers/罗伯·明可夫RobMinkoff主演:乔纳森·泰勒·托马...1994/美国/动画冒险歌舞
# 电影评分： 9.1
# 评价人数： 712592人评价
# 电影总结： 动物版《哈姆雷特》。
# --------分隔线--------
# 电影名称： 死亡诗社
# 导演与演员： 导演:彼得·威尔PeterWeir主演:罗宾·威廉姆斯RobinWilliams/罗伯...1989/美国/剧情
# 电影评分： 9.1
# 评价人数： 600337人评价
# 电影总结： 当一个死水般的体制内出现一个活跃的变数时，所有的腐臭都站在了光明的对面。
# --------分隔线--------
# 电影名称： 黑客帝国
# 导演与演员： 导演:安迪·沃卓斯基AndyWachowski/拉娜·沃卓斯基LanaWachowski主...1999/美国/动作科幻
# 电影评分： 9.1
# 评价人数： 702913人评价
# 电影总结： 视觉革命。
# --------分隔线--------
# 电影名称： 搏击俱乐部
# 导演与演员： 导演:大卫·芬奇DavidFincher主演:爱德华·诺顿EdwardNorton/布拉...1999/美国德国意大利/剧情动作悬疑惊悚
# 电影评分： 9.0
# 评价人数： 729400人评价
# 电影总结： 邪恶与平庸蛰伏于同一个母体，在特定的时间互相对峙。
# --------分隔线--------
# 电影名称： 海蒂和爷爷
# 导演与演员： 导演:阿兰·葛斯彭纳AlainGsponer主演:阿努克·斯特芬AnukSteffen/...2015/德国瑞士/剧情冒险家庭
# 电影评分： 9.2
# 评价人数： 422479人评价
# 电影总结： 如果生活中有什么使你感到快乐，那就去做吧！不要管别人说什么。
# --------分隔线--------
# 电影名称： 绿皮书
# 导演与演员： 导演:彼得·法雷里PeterFarrelly主演:维果·莫腾森ViggoMortensen/...2018/美国中国大陆/剧情喜剧传记音乐
# 电影评分： 8.9
# 评价人数： 1353368人评价
# 电影总结： 去除成见，需要勇气。
# --------分隔线--------
# 电影名称： 饮食男女
# 导演与演员： 导演:李安AngLee主演:郎雄SihungLung/杨贵媚Kuei-MeiYang/吴...1994/中国台湾美国/剧情家庭
# 电影评分： 9.1
# 评价人数： 514347人评价
# 电影总结： 人生不能像做菜，把所有的料都准备好了才下锅。
# --------分隔线--------
# 电影名称： 美丽心灵
# 导演与演员： 导演:朗·霍华德RonHoward主演:罗素·克劳RussellCrowe/艾德·哈...2001/美国/传记剧情
# 电影评分： 9.0
# 评价人数： 655422人评价
# 电影总结： 爱是一切逻辑和原由。
# --------分隔线--------
# 电影名称： 窃听风暴
# 导演与演员： 导演:弗洛里安·亨克尔·冯·多纳斯马尔克FlorianHenckelvonDonnersmarck&n...2006/德国/剧情悬疑
# 电影评分： 9.2
# 评价人数： 482503人评价
# 电影总结： 别样人生。
# --------分隔线--------
# 电影名称： 本杰明·巴顿奇事
# 导演与演员： 导演:大卫·芬奇DavidFincher主演:凯特·布兰切特CateBlanchett/...2008/美国/剧情爱情奇幻
# 电影评分： 8.9
# 评价人数： 847018人评价
# 电影总结： 在时间之河里感受溺水之苦。
# --------分隔线--------
# 电影名称： 两杆大烟枪
# 导演与演员： 导演:GuyRitchie主演:JasonFlemyng/DexterFletcher/NickMoran1998/英国/剧情喜剧犯罪
# 电影评分： 9.1
# 评价人数： 519242人评价
# 电影总结： 4个臭皮匠顶个诸葛亮，盖·里奇果然不是盖的。
# --------分隔线--------
# 电影名称： 情书
# 导演与演员： 导演:岩井俊二ShunjiIwai主演:中山美穗MihoNakayama/丰川悦司Ets...1995/日本/剧情爱情
# 电影评分： 8.9
# 评价人数： 890567人评价
# 电影总结： 暗恋的极致。
# --------分隔线--------
# 电影名称： 穿条纹睡衣的男孩
# 导演与演员： 导演:马克·赫尔曼MarkHerman主演:阿萨·巴特菲尔德AsaButterfield...2008/英国美国/剧情战争
# 电影评分： 9.1
# 评价人数： 455171人评价
# 电影总结： 尽管有些不切实际的幻想，这部电影依旧是一部感人肺腑的佳作。
# --------分隔线--------
# 电影名称： 看不见的客人
# 导演与演员： 导演:奥里奥尔·保罗OriolPaulo主演:马里奥·卡萨斯MarioCasas/阿...2016/西班牙/剧情犯罪悬疑惊悚
# 电影评分： 8.8
# 评价人数： 1055292人评价
# 电影总结： 你以为你以为的就是你以为的。
# --------分隔线--------
# 电影名称： 西西里的美丽传说
# 导演与演员： 导演:朱塞佩·托纳多雷GiuseppeTornatore主演:莫妮卡·贝鲁奇Monica...2000/意大利美国/剧情战争情色
# 电影评分： 8.9
# 评价人数： 839284人评价
# 电影总结： 美丽无罪。
# --------分隔线--------
# 电影名称： 飞越疯人院
# 导演与演员： 导演:米洛斯·福尔曼MilošForman主演:杰克·尼科尔森JackNichols...1975/美国/剧情
# 电影评分： 9.1
# 评价人数： 487789人评价
# 电影总结： 自由万岁。
# --------分隔线--------
# 电影名称： 拯救大兵瑞恩
# 导演与演员： 导演:史蒂文·斯皮尔伯格StevenSpielberg主演:汤姆·汉克斯TomHanks...1998/美国/剧情战争
# 电影评分： 9.0
# 评价人数： 555725人评价
# 电影总结： 美利坚精神输出大片No1.
# --------分隔线--------
# 电影名称： 音乐之声
# 导演与演员： 导演:罗伯特·怀斯RobertWise主演:朱莉·安德鲁斯JulieAndrews/克...1965/美国/剧情传记爱情歌舞
# 电影评分： 9.1
# 评价人数： 515116人评价
# 电影总结： 用音乐化解仇恨，让歌声串起美好。
# --------分隔线--------
# 电影名称： 小鞋子
# 导演与演员： 导演:马基德·马基迪MajidMajidi主演:默罕默德·阿米尔·纳吉Mohamma...1997/伊朗/剧情儿童家庭
# 电影评分： 9.2
# 评价人数： 349735人评价
# 电影总结： 奔跑的孩子是天使。
# --------分隔线--------
# 电影名称： 阿凡达
# 导演与演员： 导演:詹姆斯·卡梅隆JamesCameron主演:萨姆·沃辛顿SamWorthington...2009/美国/动作科幻冒险
# 电影评分： 8.8
# 评价人数： 1205493人评价
# 电影总结： 绝对意义上的美轮美奂。
# --------分隔线--------
# 电影名称： 海豚湾
# 导演与演员： 导演:路易·西霍尤斯LouiePsihoyos主演:RichardO'Barry/路易·西霍...2009/美国/纪录片
# 电影评分： 9.3
# 评价人数： 322341人评价
# 电影总结： 海豚的微笑，是世界上最高明的伪装。
# --------分隔线--------
# 电影名称： 致命魔术
# 导演与演员： 导演:克里斯托弗·诺兰ChristopherNolan主演:休·杰克曼HughJackman...2006/英国美国/剧情悬疑惊悚
# 电影评分： 8.9
# 评价人数： 738652人评价
# 电影总结： 孪生蝙蝠侠大战克隆金刚狼。
# --------分隔线--------
# 电影名称： 沉默的羔羊
# 导演与演员： 导演:乔纳森·戴米JonathanDemme主演:朱迪·福斯特JodieFoster/安...1991/美国/剧情犯罪惊悚
# 电影评分： 8.9
# 评价人数： 744114人评价
# 电影总结： 安东尼·霍普金斯的顶级表演。
# --------分隔线--------
# 电影名称： 美国往事
# 导演与演员： 导演:赛尔乔·莱翁内SergioLeone主演:罗伯特·德尼罗RobertDeNiro...1984/美国意大利/犯罪剧情
# 电影评分： 9.2
# 评价人数： 354716人评价
# 电影总结： 往事如烟，无处祭奠。
# --------分隔线--------
# 电影名称： 哈利·波特与死亡圣器(下)
# 导演与演员： 导演:大卫·叶茨DavidYates主演:丹尼尔·雷德克里夫DanielRadcliffe...2011/美国英国/奇幻冒险
# 电影评分： 8.9
# 评价人数： 685488人评价
# 电影总结： 10年的完美句点。
# --------分隔线--------
# 电影名称： 禁闭岛
# 导演与演员： 导演:MartinScorsese主演:莱昂纳多·迪卡普里奥LeonardoDiCaprio/...2010/美国/剧情悬疑惊悚
# 电影评分： 8.8
# 评价人数： 820032人评价
# 电影总结： 昔日翩翩少年，今日大腹便便。
# --------分隔线--------
# 电影名称： 蝴蝶效应
# 导演与演员： 导演:埃里克·布雷斯EricBress/J·麦基·格鲁伯J.MackyeGruber主...2004/美国加拿大/剧情悬疑科幻惊悚
# 电影评分： 8.8
# 评价人数： 801917人评价
# 电影总结： 人的命运被自己瞬间的抉择改变。
# --------分隔线--------
# 电影名称： 布达佩斯大饭店
# 导演与演员： 导演:韦斯·安德森WesAnderson主演:拉尔夫·费因斯RalphFiennes/...2014/美国德国英国/剧情喜剧冒险
# 电影评分： 8.9
# 评价人数： 769588人评价
# 电影总结： 小清新的故事里注入了大历史的情怀。
# --------分隔线--------
# 电影名称： 心灵捕手
# 导演与演员： 导演:格斯·范·桑特GusVanSant主演:马特·达蒙MattDamon/罗宾·...1997/美国/剧情
# 电影评分： 8.9
# 评价人数： 606284人评价
# 电影总结： 人生中应该拥有这样的一段豁然开朗。
# --------分隔线--------
# 电影名称： 低俗小说
# 导演与演员： 导演:昆汀·塔伦蒂诺QuentinTarantino主演:约翰·特拉沃尔塔JohnTra...1994/美国/剧情喜剧犯罪
# 电影评分： 8.9
# 评价人数： 712917人评价
# 电影总结： 故事的高级讲法。
# --------分隔线--------
# 电影名称： 春光乍泄
# 导演与演员： 导演:王家卫KarWaiWong主演:张国荣LeslieCheung/梁朝伟TonyLeu...1997/中国香港日本韩国/剧情爱情同性
# 电影评分： 9.0
# 评价人数： 537793人评价
# 电影总结： 爱情纠缠，男女一致。
# --------分隔线--------
# 电影名称： 七宗罪
# 导演与演员： 导演:大卫·芬奇DavidFincher主演:摩根·弗里曼MorganFreeman/布...1995/美国/剧情犯罪悬疑惊悚
# 电影评分： 8.8
# 评价人数： 826116人评价
# 电影总结： 警察抓小偷，老鼠玩死猫。
# --------分隔线--------
# 电影名称： 摩登时代
# 导演与演员： 导演:查理·卓别林CharlesChaplin主演:查理·卓别林CharlesChaplin...1936/美国/剧情喜剧爱情
# 电影评分： 9.3
# 评价人数： 251220人评价
# 电影总结： 大时代中的人生，小人物的悲喜。
# --------分隔线--------
# 电影名称： 喜剧之王
# 导演与演员： 导演:周星驰StephenChow/李力持Lik-ChiLee主演:周星驰StephenCh...1999/中国香港/喜剧剧情爱情
# 电影评分： 8.8
# 评价人数： 825681人评价
# 电影总结： 我是一个演员。
# --------分隔线--------
# 电影名称： 致命ID
# 导演与演员： 导演:詹姆斯·曼高德JamesMangold主演:约翰·库萨克JohnCusack/雷...2003/美国/剧情悬疑惊悚
# 电影评分： 8.8
# 评价人数： 691234人评价
# 电影总结： 最不可能的那个人永远是最可能的。
# --------分隔线--------
# 电影名称： 被嫌弃的松子的一生
# 导演与演员： 导演:中岛哲也TetsuyaNakashima主演:中谷美纪MikiNakatani/瑛太E...2006/日本/剧情歌舞
# 电影评分： 8.9
# 评价人数： 623427人评价
# 电影总结： 以戏谑来戏谑戏谑。
# --------分隔线--------
# 电影名称： 杀人回忆
# 导演与演员： 导演:奉俊昊Joon-hoBong主演:宋康昊Kang-hoSong/金相庆Sang-kyun...2003/韩国/剧情动作犯罪悬疑惊悚
# 电影评分： 8.9
# 评价人数： 587297人评价
# 电影总结： 关于连环杀人悬案的集体回忆。
# --------分隔线--------
# 电影名称： 加勒比海盗
# 导演与演员： 导演:戈尔·维宾斯基GoreVerbinski主演:约翰尼·德普JohnnyDepp/...2003/美国/动作冒险奇幻
# 电影评分： 8.8
# 评价人数： 744694人评价
# 电影总结： 约翰尼·德普的独角戏。
# --------分隔线--------
# 电影名称： 红辣椒
# 导演与演员： 导演:今敏SatoshiKon主演:林原惠美MegumiHayashibara/江守彻Toru...2006/日本/动画悬疑科幻惊悚
# 电影评分： 9.0
# 评价人数： 370783人评价
# 电影总结： 梦的勾结。
# --------分隔线--------
# 电影名称： 剪刀手爱德华
# 导演与演员： 导演:蒂姆·波顿TimBurton主演:约翰尼·德普JohnnyDepp/薇诺娜·...1990/美国/剧情奇幻爱情
# 电影评分： 8.7
# 评价人数： 928362人评价
# 电影总结： 浪漫忧郁的成人童话。
# --------分隔线--------
# 电影名称： 狩猎
# 导演与演员： 导演:托马斯·温特伯格ThomasVinterberg主演:麦斯·米科尔森MadsMik...2012/丹麦瑞典/剧情
# 电影评分： 9.1
# 评价人数： 323912人评价
# 电影总结： 人言可畏。
# --------分隔线--------
# 电影名称： 请以你的名字呼唤我
# 导演与演员： 导演:卢卡·瓜达尼诺LucaGuadagnino主演:艾米·汉莫ArmieHammer/...2017/意大利法国巴西美国荷兰德国/剧情爱情同性
# 电影评分： 8.9
# 评价人数： 595025人评价
# 电影总结： 沉醉在电影的情感和视听氛围中无法自拔。
# --------分隔线--------
# 电影名称： 勇敢的心
# 导演与演员： 导演:梅尔·吉布森MelGibson主演:梅尔·吉布森MelGibson/苏菲·玛...1995/美国/动作传记剧情历史战争
# 电影评分： 8.9
# 评价人数： 505946人评价
# 电影总结： 史诗大片的典范。
# --------分隔线--------
# 电影名称： 7号房的礼物
# 导演与演员： 导演:李焕庆Hwan-kyeongLee主演:柳承龙Seung-yongRyoo/朴信惠Shi...2013/韩国/剧情喜剧家庭
# 电影评分： 8.9
# 评价人数： 470102人评价
# 电影总结： 《我是山姆》的《美丽人生》。
# --------分隔线--------
# 电影名称： 断背山
# 导演与演员： 导演:李安AngLee主演:希斯·莱杰HeathLedger/杰克·吉伦哈尔Jake...2005/美国加拿大/剧情爱情同性家庭
# 电影评分： 8.8
# 评价人数： 622145人评价
# 电影总结： 每个人心中都有一座断背山。
# --------分隔线--------
# 电影名称： 功夫
# 导演与演员： 导演:周星驰StephenChow主演:周星驰StephenChow/元秋QiuYuen/...2004/中国大陆中国香港/动作喜剧犯罪奇幻
# 电影评分： 8.7
# 评价人数： 899446人评价
# 电影总结： 警恶惩奸，维护世界和平这个任务就交给你了，好吗？
# --------分隔线--------
# 电影名称： 超脱
# 导演与演员： 导演:托尼·凯耶TonyKaye主演:艾德里安·布洛迪AdrienBrody/马西...2011/美国/剧情
# 电影评分： 8.9
# 评价人数： 445529人评价
# 电影总结： 穷尽一生，我们要学会的，不过是彼此拥抱。
# --------分隔线--------
# 电影名称： 天使爱美丽
# 导演与演员： 导演:让-皮埃尔·热内Jean-PierreJeunet主演:奥黛丽·塔图AudreyTau...2001/法国德国/剧情喜剧爱情
# 电影评分： 8.7
# 评价人数： 872465人评价
# 电影总结： 法式小清新。
# --------分隔线--------
# 电影名称： 哈利·波特与阿兹卡班的囚徒
# 导演与演员： 导演:AlfonsoCuarón主演:丹尼尔·雷德克里夫DanielRadcliffe/Emma...2004/英国美国/奇幻冒险
# 电影评分： 8.8
# 评价人数： 566894人评价
# 电影总结： 不一样的导演，不一样的哈利·波特。
# --------分隔线--------
# 电影名称： 第六感
# 导演与演员： 导演:M·奈特·沙马兰M.NightShyamalan主演:布鲁斯·威利斯BruceWi...1999/美国/剧情悬疑惊悚
# 电影评分： 8.9
# 评价人数： 474309人评价
# 电影总结： 深入内心的恐怖，出人意料的结局。
# --------分隔线--------
# 电影名称： 唐伯虎点秋香
# 导演与演员： 导演:李力持Lik-ChiLee主演:周星驰StephenChow/巩俐LiGong/陈...1993/中国香港/喜剧爱情古装
# 电影评分： 8.7
# 评价人数： 910132人评价
# 电影总结： 华太师是黄霑，吴镇宇四大才子之一。
# --------分隔线--------
# 电影名称： 幽灵公主
# 导演与演员： 导演:宫崎骏HayaoMiyazaki主演:松田洋治YôjiMatsuda/石田百合...1997/日本/动画奇幻冒险
# 电影评分： 8.9
# 评价人数： 458440人评价
# 电影总结： 人与自然的战争史诗。
# --------分隔线--------
# 电影名称： 重庆森林
# 导演与演员： 导演:王家卫KarWaiWong主演:林青霞BrigitteLin/金城武TakeshiK...1994/中国香港/剧情爱情
# 电影评分： 8.8
# 评价人数： 684091人评价
# 电影总结： 寂寞没有期限。
# --------分隔线--------
# 电影名称： 小森林夏秋篇
# 导演与演员： 导演:森淳一JunichiMori主演:桥本爱AiHashimoto/三浦贵大Takahir...2014/日本/剧情
# 电影评分： 9.0
# 评价人数： 365489人评价
# 电影总结： 那些静得只能听见呼吸的日子里，你明白孤独即生活。
# --------分隔线--------
# 电影名称： 阳光灿烂的日子
# 导演与演员： 导演:姜文WenJiang主演:夏雨YuXia/宁静JingNing/陶虹HongTao1994/中国大陆中国香港/剧情爱情
# 电影评分： 8.8
# 评价人数： 532570人评价
# 电影总结： 一场华丽的意淫。
# --------分隔线--------
# 电影名称： 入殓师
# 导演与演员： 导演:泷田洋二郎YôjirôTakita主演:本木雅弘MasahiroMotoki/...2008/日本/剧情
# 电影评分： 8.9
# 评价人数： 540367人评价
# 电影总结： 死可能是一道门，逝去并不是终结，而是超越，走向下一程。
# --------分隔线--------
# 电影名称： 爱在黎明破晓前
# 导演与演员： 导演:理查德·林克莱特RichardLinklater主演:伊桑·霍克EthanHawke...1995/美国奥地利瑞士/剧情爱情
# 电影评分： 8.8
# 评价人数： 549798人评价
# 电影总结： 缘分是个连绵词，最美不过一瞬。
# --------分隔线--------
# 电影名称： 一一
# 导演与演员： 导演:杨德昌EdwardYang主演:吴念真/李凯莉KellyLee/金燕玲Elai...2000/中国台湾日本/剧情爱情家庭
# 电影评分： 9.1
# 评价人数： 309429人评价
# 电影总结： 我们都曾经是一一。
# --------分隔线--------
# 电影名称： 蝙蝠侠：黑暗骑士崛起
# 导演与演员： 导演:克里斯托弗·诺兰ChristopherNolan主演:克里斯蒂安·贝尔Christ...2012/美国英国/剧情动作科幻犯罪惊悚
# 电影评分： 8.8
# 评价人数： 615051人评价
# 电影总结： 诺兰就是保证。
# --------分隔线--------
# 电影名称： 菊次郎的夏天
# 导演与演员： 导演:北野武TakeshiKitano主演:北野武TakeshiKitano/关口雄介Yus...1999/日本/剧情喜剧
# 电影评分： 8.8
# 评价人数： 500733人评价
# 电影总结： 从没见过那么流氓的温柔，从没见过那么温柔的流氓。
# --------分隔线--------
# 电影名称： 消失的爱人
# 导演与演员： 导演:大卫·芬奇DavidFincher主演:本·阿弗莱克BenAffleck/罗莎蒙...2014/美国/剧情犯罪悬疑惊悚
# 电影评分： 8.7
# 评价人数： 784306人评价
# 电影总结： 年度最佳date movie。
# --------分隔线--------
# 电影名称： 无人知晓
# 导演与演员： 导演:是枝裕和HirokazuKoreeda主演:柳乐优弥YûyaYagira/北浦爱...2004/日本/剧情
# 电影评分： 9.1
# 评价人数： 260470人评价
# 电影总结： 我的平常生活就是他人的幸福。
# --------分隔线--------
# 电影名称： 超能陆战队
# 导演与演员： 导演:唐·霍尔DonHall/克里斯·威廉姆斯ChrisWilliams主演:斯科特...2014/美国/喜剧动作科幻动画冒险
# 电影评分： 8.7
# 评价人数： 867172人评价
# 电影总结： Balalala~~~
# --------分隔线--------
# 电影名称： 小森林冬春篇
# 导演与演员： 导演:森淳一JunichiMori主演:桥本爱AiHashimoto/三浦贵大Takahir...2015/日本/剧情
# 电影评分： 9.0
# 评价人数： 326513人评价
# 电影总结： 尊敬他人，尊敬你生活的这片土地，明白孤独是人生的常态。
# --------分隔线--------
# 电影名称： 哈利·波特与密室
# 导演与演员： 导演:ChrisColumbus主演:丹尼尔·雷德克里夫DanielRadcliffe/艾玛...2002/英国美国/奇幻冒险
# 电影评分： 8.8
# 评价人数： 593208人评价
# 电影总结： 魔法的密室之门已打开...
# --------分隔线--------
# 电影名称： 完美的世界
# 导演与演员： 导演:克林特·伊斯特伍德ClintEastwood主演:凯文·科斯特纳KevinCos...1993/美国/剧情犯罪
# 电影评分： 9.1
# 评价人数： 252470人评价
# 电影总结： 坏人的好总是比好人的好来得更感人。
# --------分隔线--------
# 电影名称： 倩女幽魂
# 导演与演员： 导演:程小东Siu-TungChing主演:张国荣LeslieCheung/王祖贤JoeyW...1987/中国香港/爱情奇幻武侠古装
# 电影评分： 8.7
# 评价人数： 633262人评价
# 电影总结： 两张绝世的脸。
# --------分隔线--------
# 电影名称： 侧耳倾听
# 导演与演员： 导演:近藤喜文YoshifumiKondo主演:本名阳子YoukoHonna/小林桂树K...1995/日本/剧情爱情动画
# 电影评分： 8.9
# 评价人数： 396505人评价
# 电影总结： 少女情怀总是诗。
# --------分隔线--------
# 电影名称： 爱在日落黄昏时
# 导演与演员： 导演:理查德·林克莱特RichardLinklater主演:伊桑·霍克EthanHawke...2004/美国法国/剧情爱情
# 电影评分： 8.9
# 评价人数： 454023人评价
# 电影总结： 九年后的重逢是世俗和责任的交叠，没了悸动和青涩，沧桑而温暖。
# --------分隔线--------
# 电影名称： 借东西的小人阿莉埃蒂
# 导演与演员： 导演:米林宏昌HiromasaYonebayashi主演:志田未来MiraiShida/神木...2010/日本/动画奇幻冒险
# 电影评分： 8.9
# 评价人数： 469785人评价
# 电影总结： 曾经的那段美好会沉淀为一辈子的记忆。
# --------分隔线--------
# 电影名称： 甜蜜蜜
# 导演与演员： 导演:陈可辛PeterChan主演:黎明LeonLai/张曼玉MaggieCheung/...1996/中国香港/剧情爱情
# 电影评分： 8.9
# 评价人数： 447262人评价
# 电影总结： 相逢只要一瞬间，等待却像是一辈子。
# --------分隔线--------
# 电影名称： 萤火之森
# 导演与演员： 导演:大森贵弘TakahiroOmori主演:佐仓绫音AyaneSakura/内山昂辉K...2011/日本/剧情爱情动画奇幻
# 电影评分： 8.9
# 评价人数： 447960人评价
# 电影总结： 触不到的恋人。
# --------分隔线--------
# 电影名称： 驯龙高手
# 导演与演员： 导演:迪恩·德布洛斯DeanDeBlois/克里斯·桑德斯ChrisSanders主演:...2010/美国/动画奇幻冒险
# 电影评分： 8.7
# 评价人数： 654724人评价
# 电影总结： 和谐的生活离不开摸头与被摸头。
# --------分隔线--------
# 电影名称： 幸福终点站
# 导演与演员： 导演:史蒂文·斯皮尔伯格StevenSpielberg主演:汤姆·汉克斯TomHanks...2004/美国/喜剧剧情爱情
# 电影评分： 8.8
# 评价人数： 473218人评价
# 电影总结： 有时候幸福需要等一等。
# --------分隔线--------
# 电影名称： 玛丽和马克思
# 导演与演员： 导演:亚当·艾略特AdamElliot主演:托妮·科莱特ToniCollette/菲利...2009/澳大利亚美国/剧情喜剧动画
# 电影评分： 8.9
# 评价人数： 379880人评价
# 电影总结： 你是我最好的朋友，你是我唯一的朋友 。
# --------分隔线--------
# 电影名称： 时空恋旅人
# 导演与演员： 导演:理查德·柯蒂斯RichardCurtis主演:多姆纳尔·格里森DomhnallGl...2013/英国/喜剧爱情奇幻
# 电影评分： 8.8
# 评价人数： 526873人评价
# 电影总结： 把每天当作最后一天般珍惜度过，积极拥抱生活，就是幸福。
# --------分隔线--------
# 电影名称： 大鱼
# 导演与演员： 导演:蒂姆·波顿TimBurton主演:伊万·麦克格雷格EwanMcGregor/阿...2003/美国/剧情家庭奇幻冒险
# 电影评分： 8.8
# 评价人数： 494499人评价
# 电影总结： 抱着梦想而活着的人是幸福的，怀抱梦想而死去的人是不朽的。
# --------分隔线--------
# 电影名称： 告白
# 导演与演员： 导演:中岛哲也TetsuyaNakashima主演:松隆子TakakoMatsu/冈田将生...2010/日本/剧情悬疑
# 电影评分： 8.8
# 评价人数： 600712人评价
# 电影总结： 没有一人完全善，也没有一人完全恶。
# --------分隔线--------
# 电影名称： 怪兽电力公司
# 导演与演员： 导演:彼特·道格特PeteDocter/大卫·斯沃曼DavidSilverman主演:约...2001/美国/儿童喜剧动画奇幻冒险
# 电影评分： 8.7
# 评价人数： 565741人评价
# 电影总结： 不要给它起名字，起了名字就有感情了。
# --------分隔线--------
# 电影名称： 阳光姐妹淘
# 导演与演员： 导演:姜炯哲Hyeong-CheolKang主演:沈恩京Eun-kyungShim/闵孝琳Hy...2011/韩国/剧情喜剧
# 电影评分： 8.8
# 评价人数： 531989人评价
# 电影总结： 再多各自牛逼的时光，也比不上一起傻逼的岁月。
# --------分隔线--------
# 电影名称： 射雕英雄传之东成西就
# 导演与演员： 导演:刘镇伟JeffreyLau主演:梁朝伟TonyLeungChiuWai/林青霞Bri...1993/中国香港/喜剧奇幻武侠古装
# 电影评分： 8.7
# 评价人数： 553803人评价
# 电影总结： 百看不厌。
# --------分隔线--------
# 电影名称： 神偷奶爸
# 导演与演员： 导演:皮艾尔·柯芬PierreCoffin/克里斯·雷纳德ChrisRenaud主演:...2010/美国法国/喜剧动画冒险
# 电影评分： 8.6
# 评价人数： 829408人评价
# 电影总结： Mr. I Don't Care其实也有Care的时候。
# --------分隔线--------
# 电影名称： 傲慢与偏见
# 导演与演员： 导演:乔·怀特JoeWright主演:凯拉·奈特莉KeiraKnightley/马修·...2005/法国英国美国/剧情爱情
# 电影评分： 8.7
# 评价人数： 673683人评价
# 电影总结： 爱是摈弃傲慢与偏见之后的曙光。
# --------分隔线--------
# 电影名称： 教父3
# 导演与演员： 导演:弗朗西斯·福特·科波拉FrancisFordCoppola主演:阿尔·帕西诺A...1990/美国/剧情犯罪
# 电影评分： 9.0
# 评价人数： 307218人评价
# 电影总结： 任何信念的力量，都无法改变命运。
# --------分隔线--------
# 电影名称： 玩具总动员3
# 导演与演员： 导演:李·昂克里奇LeeUnkrich主演:汤姆·汉克斯TomHanks/蒂姆·艾...2010/美国/喜剧动画奇幻冒险
# 电影评分： 8.9
# 评价人数： 435498人评价
# 电影总结： 跨度十五年的欢乐与泪水。
# --------分隔线--------
# 电影名称： 恐怖直播
# 导演与演员： 导演:金秉祐Byeong-wooKim主演:河正宇Jung-wooHa/李璟荣Kyeong-y...2013/韩国/剧情犯罪悬疑
# 电影评分： 8.7
# 评价人数： 559288人评价
# 电影总结： 恐怖分子的“秋菊打官司”。
# --------分隔线--------
# 电影名称： 釜山行
# 导演与演员： 导演:延尚昊Sang-hoYeon主演:孔侑YooGong/郑有美Yu-miJung/马...2016/韩国/动作惊悚灾难
# 电影评分： 8.6
# 评价人数： 1019146人评价
# 电影总结： 揭露人性的丧尸题材力作。
# --------分隔线--------
# 电影名称： 一个叫欧维的男人决定去死
# 导演与演员： 导演:汉内斯·赫尔姆HannesHolm主演:罗夫·拉斯加德RolfLassgård...2015/瑞典/剧情
# 电影评分： 8.9
# 评价人数： 368819人评价
# 电影总结： 惠及一生的美丽。
# --------分隔线--------
# 电影名称： 哪吒闹海
# 导演与演员： 导演:王树忱ShuchenWang/严定宪DingxianYan主演:梁正晖Zhenghui...1979/中国大陆/冒险动画奇幻
# 电影评分： 9.1
# 评价人数： 218024人评价
# 电影总结： 想你时你在闹海。
# --------分隔线--------
# 电影名称： 血战钢锯岭
# 导演与演员： 导演:梅尔·吉布森MelGibson主演:安德鲁·加菲尔德AndrewGarfield/...2016/澳大利亚美国/剧情传记历史战争
# 电影评分： 8.7
# 评价人数： 683851人评价
# 电影总结： 优秀的战争片不会美化战场，不会粉饰死亡，不会矮化敌人，不会无视常识，最重要的，不会宣扬战争。
# --------分隔线--------
# 电影名称： 被解救的姜戈
# 导演与演员： 导演:昆汀·塔伦蒂诺QuentinTarantino主演:杰米·福克斯JamieFoxx/...2012/美国/剧情动作西部冒险
# 电影评分： 8.8
# 评价人数： 518286人评价
# 电影总结： 热血沸腾，那个低俗、性感的无耻混蛋又来了。
# --------分隔线--------
# 电影名称： 未麻的部屋
# 导演与演员： 导演:今敏SatoshiKon主演:岩男润子JunkoIwao/松本梨香RicaMatsu...1997/日本/动画奇幻惊悚
# 电影评分： 9.0
# 评价人数： 256887人评价
# 电影总结： 好的剧本是，就算你猜到了结局也猜不到全部。
# --------分隔线--------
# 电影名称： 头号玩家
# 导演与演员： 导演:史蒂文·斯皮尔伯格StevenSpielberg主演:泰伊·谢里丹TyeSheri...2018/美国/动作科幻冒险
# 电影评分： 8.7
# 评价人数： 1184412人评价
# 电影总结： 写给影迷，动漫迷和游戏迷的一封情书。
# --------分隔线--------
# 电影名称： 七武士
# 导演与演员： 导演:黑泽明AkiraKurosawa主演:三船敏郎ToshirôMifune/志村乔...1954/日本/动作冒险剧情
# 电影评分： 9.3
# 评价人数： 165375人评价
# 电影总结： 时代悲歌。
# --------分隔线--------
# 电影名称： 我是山姆
# 导演与演员： 导演:杰茜·尼尔森JessieNelson主演:SeanPenn/DakotaFanning/Mi...2001/美国/剧情家庭
# 电影评分： 9.0
# 评价人数： 276554人评价
# 电影总结： 爱并不需要智商 。
# --------分隔线--------
# 电影名称： 喜宴
# 导演与演员： 导演:李安AngLee主演:赵文瑄WinstonChao/郎雄SihungLung/归亚...1993/中国台湾美国/剧情喜剧爱情同性家庭
# 电影评分： 8.9
# 评价人数： 294374人评价
# 电影总结： 中国家庭的喜怒哀乐忍。
# --------分隔线--------
# 电影名称： 寄生虫
# 导演与演员： 导演:奉俊昊Joon-hoBong主演:宋康昊Kang-hoSong/李善均Seon-gyun...2019/韩国/剧情喜剧
# 电影评分： 8.8
# 评价人数： 1176461人评价
# 电影总结：
# --------分隔线--------
# 电影名称： 电锯惊魂
# 导演与演员： 导演:詹姆斯·温JamesWan主演:雷·沃纳尔LeighWhannell/加利·艾...2004/美国/悬疑惊悚恐怖
# 电影评分： 8.7
# 评价人数： 449099人评价
# 电影总结： 真相就在眼前。
# --------分隔线--------
# 电影名称： 新世界
# 导演与演员： 导演:朴勋政Hoon-jungPark主演:李政宰Jung-JaeLee/崔岷植Min-sik...2013/韩国/剧情犯罪
# 电影评分： 8.9
# 评价人数： 325922人评价
# 电影总结： 要做就做得狠一点，这样才能活下去。
# --------分隔线--------
# 电影名称： 模仿游戏
# 导演与演员： 导演:莫滕·泰杜姆MortenTyldum主演:本尼迪克特·康伯巴奇BenedictC...2014/英国美国/剧情传记战争同性
# 电影评分： 8.7
# 评价人数： 533704人评价
# 电影总结： 他给机器起名“克里斯托弗”，因为这是他初恋的名字。
# --------分隔线--------
# 电影名称： 花样年华
# 导演与演员： 导演:王家卫KarWaiWong主演:梁朝伟TonyLeungChiuWai/张曼玉Ma...2000/中国香港/剧情爱情
# 电影评分： 8.7
# 评价人数： 501549人评价
# 电影总结： 偷情本没有这样美。
# --------分隔线--------
# 电影名称： 黑客帝国3：矩阵革命
# 导演与演员： 导演:拉娜·沃卓斯基LanaWachowski/莉莉·沃卓斯基LillyWachowski...2003/美国/动作科幻
# 电影评分： 8.8
# 评价人数： 375976人评价
# 电影总结： 不得不说，《黑客帝国》系列是商业片与科幻、哲学完美结合的典范。
# --------分隔线--------
# 电影名称： 卢旺达饭店
# 导演与演员： 导演:特瑞·乔治TerryGeorge主演:唐·钱德尔DonCheadle/苏菲·奥...2004/英国南非意大利美国/剧情传记历史战争
# 电影评分： 8.9
# 评价人数： 274230人评价
# 电影总结： 当这个世界闭上双眼，他却敞开了怀抱。
# --------分隔线--------
# 电影名称： 三块广告牌
# 导演与演员： 导演:马丁·麦克唐纳MartinMcDonagh主演:弗兰西斯·麦克多蒙德France...2017/美国英国/剧情犯罪
# 电影评分： 8.7
# 评价人数： 712740人评价
# 电影总结： 怼天怼地，你走后，她与世界为敌。
# --------分隔线--------
# 电影名称： 上帝之城
# 导演与演员： 导演:费尔南多·梅里尔斯FernandoMeirelles/卡迪亚·兰德KátiaLund&nbsp...2002/巴西法国/犯罪剧情
# 电影评分： 9.0
# 评价人数： 265222人评价
# 电影总结： 被上帝抛弃了的上帝之城。
# --------分隔线--------
# 电影名称： 风之谷
# 导演与演员： 导演:宫崎骏HayaoMiyazaki主演:岛本须美SumiShimamoto/松田洋治Y...1984/日本/动画奇幻冒险
# 电影评分： 8.9
# 评价人数： 316428人评价
# 电影总结： 动画片的圣经。
# --------分隔线--------
# 电影名称： 哈利·波特与火焰杯
# 导演与演员： 导演:迈克·内威尔MikeNewell主演:丹尼尔·雷德克里夫DanielRadclif...2005/英国美国/悬疑奇幻冒险
# 电影评分： 8.7
# 评价人数： 513921人评价
# 电影总结：
# --------分隔线--------
# 电影名称： 疯狂原始人
# 导演与演员： 导演:科克·德·米科KirkDeMicco/克里斯·桑德斯ChrisSanders主演...2013/美国/喜剧动画冒险
# 电影评分： 8.7
# 评价人数： 738912人评价
# 电影总结： 老少皆宜，这就是好莱坞动画的魅力。
# --------分隔线--------
# 电影名称： 谍影重重3
# 导演与演员： 导演:保罗·格林格拉斯PaulGreengrass主演:马特·达蒙MattDamon/...2007/美国德国/动作悬疑惊悚
# 电影评分： 8.8
# 评价人数： 365477人评价
# 电影总结： 像吃了苏打饼一样干脆的电影。
# --------分隔线--------
# 电影名称： 英雄本色
# 导演与演员： 导演:吴宇森JohnWoo主演:周润发Yun-FatChow/狄龙LungTi/张国...1986/中国香港/剧情动作犯罪
# 电影评分： 8.6
# 评价人数： 450643人评价
# 电影总结： 英雄泪短，兄弟情长。
# --------分隔线--------
# 电影名称： 你的名字。
# 导演与演员： 导演:新海诚MakotoShinkai主演:神木隆之介RyûnosukeKamiki/上...2016/日本/剧情爱情动画
# 电影评分： 8.5
# 评价人数： 1191755人评价
# 电影总结： 穿越错位的时空，仰望陨落的星辰，你没留下你的名字，我却无法忘记那句“我爱你”。
# --------分隔线--------
# 电影名称： 头脑特工队
# 导演与演员： 导演:彼特·道格特PeteDocter/罗纳尔多·德尔·卡门RonaldoDelCarmen&nb...2015/美国/喜剧动画冒险
# 电影评分： 8.7
# 评价人数： 511794人评价
# 电影总结： 愿我们都不用长大，每一座城堡都能永远存在。
# --------分隔线--------
# 电影名称： 达拉斯买家俱乐部
# 导演与演员： 导演:让-马克·瓦雷Jean-MarcVallée主演:马修·麦康纳MatthewMcCon...2013/美国/剧情传记同性
# 电影评分： 8.8
# 评价人数： 387111人评价
# 电影总结： Jared Leto的腿比女人还美！
# --------分隔线--------
# 电影名称： 纵横四海
# 导演与演员： 导演:吴宇森JohnWoo主演:周润发Yun-FatChow/张国荣LeslieCheung...1991/中国香港/剧情喜剧动作犯罪
# 电影评分： 8.8
# 评价人数： 355721人评价
# 电影总结： 香港浪漫主义警匪动作片的巅峰之作。
# --------分隔线--------
# 电影名称： 心迷宫
# 导演与演员： 导演:忻钰坤YukunXin主演:霍卫民WeiminHuo/王笑天XiaotianWang...2014/中国大陆/剧情犯罪悬疑
# 电影评分： 8.7
# 评价人数： 430664人评价
# 电影总结： 荒诞讽刺，千奇百巧，抽丝剥茧，百转千回。
# --------分隔线--------
# 电影名称： 岁月神偷
# 导演与演员： 导演:罗启锐AlexLaw主演:吴君如SandraNg/任达华SimonYam/钟绍...2010/中国香港中国大陆/剧情家庭
# 电影评分： 8.7
# 评价人数： 518407人评价
# 电影总结： 岁月流逝，来日可追。
# --------分隔线--------
# 电影名称： 记忆碎片
# 导演与演员： 导演:克里斯托弗·诺兰ChristopherNolan主演:盖·皮尔斯GuyPearce/...2000/美国/犯罪剧情悬疑惊悚
# 电影评分： 8.7
# 评价人数： 528209人评价
# 电影总结： 一个针管引发的血案。
# --------分隔线--------
# 电影名称： 忠犬八公物语
# 导演与演员： 导演:SeijirôKôyama主演:山本圭KeiYamamoto/井川比佐志Hisa...1987/日本/剧情
# 电影评分： 9.2
# 评价人数： 164946人评价
# 电影总结： 养狗三日，便会对你终其一生。
# --------分隔线--------
# 电影名称： 海街日记
# 导演与演员： 导演:是枝裕和HirokazuKoreeda主演:绫濑遥HarukaAyase/长泽雅美M...2015/日本/剧情家庭
# 电影评分： 8.8
# 评价人数： 369974人评价
# 电影总结： 是枝裕和的家庭习作。
# --------分隔线--------
# 电影名称： 惊魂记
# 导演与演员： 导演:阿尔弗雷德·希区柯克AlfredHitchcock主演:安东尼·博金斯Antho...1960/美国/悬疑惊悚恐怖
# 电影评分： 9.0
# 评价人数： 226429人评价
# 电影总结： 故事的反转与反转，分裂电影的始祖。
# --------分隔线--------
# 电影名称： 荒蛮故事
# 导演与演员： 导演:达米安·斯兹弗隆DamiánSzifron主演:达里奥·葛兰帝内提Darío...2014/阿根廷西班牙/剧情喜剧犯罪
# 电影评分： 8.8
# 评价人数： 375006人评价
# 电影总结： 始于荒诞，止于更荒诞。
# --------分隔线--------
# 电影名称： 爆裂鼓手
# 导演与演员： 导演:达米恩·查泽雷DamienChazelle主演:迈尔斯·特勒MilesTeller/...2014/美国/剧情音乐
# 电影评分： 8.7
# 评价人数： 489663人评价
# 电影总结： 这个世界从不善待努力的人，努力了也不一定会成功，但是知道自己在努力，就是活下去的动力。
# --------分隔线--------
# 电影名称： 九品芝麻官
# 导演与演员： 导演:王晶JingWong主演:周星驰StephenChow/吴孟达ManTatNg/...1994/中国香港中国大陆/剧情喜剧古装
# 电影评分： 8.6
# 评价人数： 537963人评价
# 电影总结：
# --------分隔线--------
# 电影名称： 贫民窟的百万富翁
# 导演与演员： 导演:丹尼·鲍尔DannyBoyle/洛芙琳·坦丹LoveleenTandan主演:戴夫...2008/英国/剧情爱情
# 电影评分： 8.6
# 评价人数： 654332人评价
# 电影总结： 上帝之城+猜火车+阿甘正传+开心辞典=山寨富翁
# --------分隔线--------
# 电影名称： 真爱至上
# 导演与演员： 导演:理查德·柯蒂斯RichardCurtis主演:休·格兰特HughGrant/柯林...2003/英国美国法国/喜剧剧情爱情
# 电影评分： 8.6
# 评价人数： 622710人评价
# 电影总结： 爱，是个动词。
# --------分隔线--------
# 电影名称： 东邪西毒
# 导演与演员： 导演:王家卫KarWaiWong主演:张国荣LeslieCheung/林青霞Brigitte...1994/中国香港中国台湾/剧情动作爱情武侠古装
# 电影评分： 8.6
# 评价人数： 506943人评价
# 电影总结： 电影诗。
# --------分隔线--------
# 电影名称： 绿里奇迹
# 导演与演员： 导演:FrankDarabont主演:汤姆·汉克斯TomHanks/大卫·摩斯DavidM...1999/美国/犯罪剧情奇幻悬疑
# 电影评分： 8.9
# 评价人数： 265127人评价
# 电影总结： 天使暂时离开。
# --------分隔线--------
# 电影名称： 小偷家族
# 导演与演员： 导演:是枝裕和HirokazuKoreeda主演:中川雅也LilyFranky/安藤樱Sa...2018/日本/剧情犯罪家庭
# 电影评分： 8.7
# 评价人数： 714401人评价
# 电影总结： 我们组成了家。
# --------分隔线--------
# 电影名称： 爱在午夜降临前
# 导演与演员： 导演:理查德·林克莱特RichardLinklater主演:伊桑·霍克EthanHawke...2013/美国希腊/剧情爱情
# 电影评分： 8.8
# 评价人数： 314439人评价
# 电影总结： 所谓爱情，就是话唠一路，都不会心生腻烦，彼此嫌弃。
# --------分隔线--------
# 电影名称： 无敌破坏王
# 导演与演员： 导演:瑞奇·莫尔RichMoore主演:约翰·C·赖利JohnC.Reilly/萨拉...2012/美国/喜剧动画奇幻冒险
# 电影评分： 8.7
# 评价人数： 457913人评价
# 电影总结： 迪士尼和皮克斯拿错剧本的产物。
# --------分隔线--------
# 电影名称： 黑天鹅
# 导演与演员： 导演:达伦·阿罗诺夫斯基DarrenAronofsky主演:娜塔莉·波特曼Natalie...2010/美国/剧情惊悚
# 电影评分： 8.6
# 评价人数： 706980人评价
# 电影总结： 黑暗之美。
# --------分隔线--------
# 电影名称： 冰川时代
# 导演与演员： 导演:卡洛斯·沙尔丹哈CarlosSaldanha/克里斯·韦奇ChrisWedge主演...2002/美国/喜剧动画冒险
# 电影评分： 8.6
# 评价人数： 534897人评价
# 电影总结： 松鼠才是角儿。
# --------分隔线--------
# 电影名称： 你看起来好像很好吃
# 导演与演员： 导演:藤森雅也MasayaFujimori主演:山口胜平KappeiYamaguchi/爱河...2010/日本/剧情动画儿童
# 电影评分： 8.9
# 评价人数： 290281人评价
# 电影总结： 感情不分食草或者食肉。
# --------分隔线--------
# 电影名称： 萤火虫之墓
# 导演与演员： 导演:高畑勋IsaoTakahata主演:辰己努/白石绫乃/志乃原良子1988/日本/动画剧情战争
# 电影评分： 8.7
# 评价人数： 364883人评价
# 电影总结： 幸福是生生不息，却难以触及的远。
# --------分隔线--------
# 电影名称： 疯狂的石头
# 导演与演员： 导演:宁浩HaoNing主演:郭涛TaoGuo/刘桦HuaLiu/连晋TeddyLin2006/中国大陆中国香港/喜剧犯罪
# 电影评分： 8.5
# 评价人数： 695140人评价
# 电影总结： 中国版《两杆大烟枪》。
# --------分隔线--------
# 电影名称： 雨人
# 导演与演员： 导演:巴瑞·莱文森BarryLevinson主演:达斯汀·霍夫曼DustinHoffman...1988/美国/剧情
# 电影评分： 8.7
# 评价人数： 354970人评价
# 电影总结： 生活在自己的世界里，也可以让周围的人显得可笑和渺小。
# --------分隔线--------
# 电影名称： 雨中曲
# 导演与演员： 导演:斯坦利·多南StanleyDonen/吉恩·凯利GeneKelly主演:吉恩·...1952/美国/喜剧歌舞爱情
# 电影评分： 9.1
# 评价人数： 181022人评价
# 电影总结： 骨灰级歌舞片。
# --------分隔线--------
# 电影名称： 恐怖游轮
# 导演与演员： 导演:克里斯托弗·史密斯ChristopherSmith主演:梅利莎·乔治Melissa...2009/英国澳大利亚/剧情悬疑惊悚
# 电影评分： 8.5
# 评价人数： 691700人评价
# 电影总结： 不要企图在重复中寻找已经失去的爱。
# --------分隔线--------
# 电影名称： 色，戒
# 导演与演员： 导演:李安AngLee主演:梁朝伟TonyLeungChiuWai/汤唯WeiTang/...2007/中国台湾中国大陆美国中国香港/剧情爱情情色
# 电影评分： 8.5
# 评价人数： 617642人评价
# 电影总结： 假戏真情，爱欲深海
# --------分隔线--------
# 电影名称： 恋恋笔记本
# 导演与演员： 导演:尼克·卡索维茨NickCassavetes主演:瑞恩·高斯林RyanGosling/...2004/美国/剧情爱情
# 电影评分： 8.6
# 评价人数： 569224人评价
# 电影总结： 爱情没有那么多借口，如果不能圆满，只能说明爱的不够。
# --------分隔线--------
# 电影名称： 魔女宅急便
# 导演与演员： 导演:宫崎骏HayaoMiyazaki主演:高山南MinamiTakayama/佐久间玲Re...1989/日本/动画奇幻冒险
# 电影评分： 8.7
# 评价人数： 394503人评价
# 电影总结： 宫崎骏的电影总让人感觉世界是美好的，阳光明媚的。
# --------分隔线--------
# 电影名称： 2001太空漫游
# 导演与演员： 导演:斯坦利·库布里克StanleyKubrick主演:凯尔·杜拉KeirDullea/...1968/英国美国/科幻惊悚冒险
# 电影评分： 8.8
# 评价人数： 259805人评价
# 电影总结： 现代科幻电影的开山之作，最伟大导演的最伟大影片。
# --------分隔线--------
# 电影名称： 城市之光
# 导演与演员： 导演:CharlesChaplin主演:查理·卓别林CharlesChaplin/弗吉尼亚·...1931/美国/喜剧剧情爱情
# 电影评分： 9.3
# 评价人数： 118523人评价
# 电影总结： 永远的小人物，伟大的卓别林。
# --------分隔线--------
# 电影名称： 可可西里
# 导演与演员： 导演:陆川ChuanLu主演:多布杰Duobujie/张磊LeiZhang/亓亮QiL...2004/中国大陆中国香港/剧情犯罪
# 电影评分： 8.8
# 评价人数： 256627人评价
# 电影总结： 坚硬的信仰。
# --------分隔线--------
# 电影名称： 二十二
# 导演与演员： 导演:郭柯KeGuo主演:2015/中国大陆/纪录片
# 电影评分： 8.7
# 评价人数： 261215人评价
# 电影总结： 有一些东西不应该被遗忘。
# --------分隔线--------
# 电影名称： 虎口脱险
# 导演与演员： 导演:杰拉尔·乌里GérardOury主演:路易·德·菲耐斯LouisdeFunès...1966/法国英国/喜剧战争
# 电影评分： 8.9
# 评价人数： 211100人评价
# 电影总结： 永远看不腻的喜剧。
# --------分隔线--------
# 电影名称： 人工智能
# 导演与演员： 导演:史蒂文·斯皮尔伯格StevenSpielberg主演:海利·乔·奥斯蒙Haley...2001/美国英国/剧情科幻
# 电影评分： 8.7
# 评价人数： 379781人评价
# 电影总结： 对爱的执着，可以超越一切。
# --------分隔线--------
# 电影名称： 奇迹男孩
# 导演与演员： 导演:斯蒂芬·卓博斯基StephenChbosky主演:雅各布·特伦布莱JacobTr...2017/美国中国香港/剧情儿童家庭
# 电影评分： 8.6
# 评价人数： 490362人评价
# 电影总结： 世界不完美，爱会有奇迹。
# --------分隔线--------
# 电影名称： 初恋这件小事
# 导演与演员： 导演:普特鹏·普罗萨卡·那·萨克那卡林PuttipongPromsakaNaSakolnakorn/华森·波克彭...2010/泰国/剧情喜剧爱情
# 电影评分： 8.4
# 评价人数： 877358人评价
# 电影总结： 黑小鸭速效美白记。
# --------分隔线--------
# 电影名称： 海边的曼彻斯特
# 导演与演员： 导演:肯尼斯·罗纳根KennethLonergan主演:卡西·阿弗莱克CaseyAffle...2016/美国/剧情家庭
# 电影评分： 8.6
# 评价人数： 420208人评价
# 电影总结： 我们都有权利不与自己的过去和解。
# --------分隔线--------
# 电影名称： 遗愿清单
# 导演与演员： 导演:罗伯·莱纳RobReiner主演:杰克·尼科尔森JackNicholson/摩根...2007/美国/冒险喜剧剧情
# 电影评分： 8.7
# 评价人数： 357137人评价
# 电影总结： 用剩余不多的时间，去燃烧整个生命。
# --------分隔线--------
# 电影名称： 大佛普拉斯
# 导演与演员： 导演:黄信尧Hsin-yaoHuang主演:庄益增YizengZhuang/陈竹昇Chu-sh...2017/中国台湾/剧情喜剧
# 电影评分： 8.7
# 评价人数： 362395人评价
# 电影总结： 人们可以登上月球，却永远无法探索人们内心的宇宙。
# --------分隔线--------
# 电影名称： 罗生门
# 导演与演员： 导演:黑泽明AkiraKurosawa主演:三船敏郎ToshirôMifune/京町子...1950/日本/剧情犯罪悬疑
# 电影评分： 8.8
# 评价人数： 265293人评价
# 电影总结： 人生的N种可能性。
# --------分隔线--------
# 电影名称： 终结者2：审判日
# 导演与演员： 导演:詹姆斯·卡梅隆JamesCameron主演:阿诺·施瓦辛格ArnoldSchwarz...1991/美国法国/动作科幻
# 电影评分： 8.8
# 评价人数： 298233人评价
# 电影总结： 少见的超越首部的续集，动作片中的经典。
# --------分隔线--------
# 电影名称： 牯岭街少年杀人事件
# 导演与演员： 导演:杨德昌EdwardYang主演:张震ChenChang/杨静怡LisaYang/张...1991/中国台湾/剧情犯罪
# 电影评分： 8.9
# 评价人数： 230455人评价
# 电影总结： 弱者送给弱者的一刀。
# --------分隔线--------
# 电影名称： 房间
# 导演与演员： 导演:伦尼·阿伯拉罕森LennyAbrahamson主演:布丽·拉尔森BrieLarson...2015/爱尔兰加拿大英国美国/剧情家庭
# 电影评分： 8.8
# 评价人数： 330925人评价
# 电影总结： 被偷走的岁月，被伤害的生命，被禁锢的灵魂，终将被希望和善意救赎。
# --------分隔线--------
# 电影名称： 源代码
# 导演与演员： 导演:邓肯·琼斯DuncanJones主演:杰克·吉伦哈尔JakeGyllenhaal/...2011/美国加拿大/科幻悬疑惊悚
# 电影评分： 8.5
# 评价人数： 707917人评价
# 电影总结： 邓肯·琼斯继《月球》之后再度奉献出一部精彩绝伦的科幻佳作。
# --------分隔线--------
# 电影名称： 青蛇
# 导演与演员： 导演:徐克HarkTsui主演:张曼玉MaggieCheung/王祖贤JoeyWang/...1993/中国香港中国大陆/剧情爱情奇幻古装
# 电影评分： 8.6
# 评价人数： 447198人评价
# 电影总结： 人生如此，浮生如斯。谁人言，花彼岸，此生情长意短。谁都是不懂爱的罢了。
# --------分隔线--------
# 电影名称： 无间道2
# 导演与演员： 导演:刘伟强/麦兆辉主演:陈冠希/余文乐/曾志伟2003/中国香港/剧情犯罪惊悚
# 电影评分： 8.6
# 评价人数： 374448人评价
# 电影总结：
# --------分隔线--------
# 电影名称： 新龙门客栈
# 导演与演员： 导演:李惠民RaymondLee主演:张曼玉MaggieCheung/林青霞Brigitte...1992/中国香港中国大陆/动作爱情武侠古装
# 电影评分： 8.6
# 评价人数： 380562人评价
# 电影总结： 嬉笑怒骂，调风动月。
# --------分隔线--------
# 电影名称： 东京教父
# 导演与演员： 导演:今敏SatoshiKon主演:江守彻ToruEmori/梅垣义明YoshiakiUme...2003/日本/剧情喜剧动画
# 电影评分： 9.0
# 评价人数： 164992人评价
# 电影总结：
# --------分隔线--------
# 电影名称： 疯狂的麦克斯4：狂暴之路
# 导演与演员： 导演:乔治·米勒GeorgeMiller主演:汤姆·哈迪TomHardy/查理兹·塞...2015/澳大利亚美国/动作科幻冒险
# 电影评分： 8.6
# 评价人数： 450933人评价
# 电影总结： “多么美好的一天！”轰轰轰砰咚，啪哒哒哒轰隆隆，磅~
# --------分隔线--------
# 电影名称： 魂断蓝桥
# 导演与演员： 导演:茂文·勒鲁瓦MervynLeRoy主演:费雯·丽VivienLeigh/罗伯特·...1940/美国/剧情爱情战争
# 电影评分： 8.8
# 评价人数： 238745人评价
# 电影总结： 中国式内在的美国电影。
# --------分隔线--------
# 电影名称： 波西米亚狂想曲
# 导演与演员： 导演:布莱恩·辛格BryanSinger主演:拉米·马雷克RamiMalek/本·哈...2018/英国美国/剧情传记同性音乐
# 电影评分： 8.7
# 评价人数： 502199人评价
# 电影总结：
# --------分隔线--------
# 电影名称： 无耻混蛋
# 导演与演员： 导演:QuentinTarantino主演:布拉德·皮特BradPitt/梅拉尼·罗兰M...2009/德国美国/剧情犯罪
# 电影评分： 8.6
# 评价人数： 408933人评价
# 电影总结： 昆汀同学越来越变态了，比北野武还杜琪峰。
# --------分隔线--------
# 电影名称： 步履不停
# 导演与演员： 导演:是枝裕和HirokazuKoreeda主演:阿部宽HiroshiAbe/夏川结衣Yu...2008/日本/剧情家庭
# 电影评分： 8.8
# 评价人数： 234404人评价
# 电影总结： 日本的家庭电影已经是世界巅峰了，步履不停是巅峰中的佳作。
# --------分隔线--------
# 电影名称： 血钻
# 导演与演员： 导演:爱德华·兹威克EdwardZwick主演:莱昂纳多·迪卡普里奥Leonardo...2006/美国德国英国/剧情惊悚冒险
# 电影评分： 8.7
# 评价人数： 318358人评价
# 电影总结： 每个美丽事物背后都是滴血的现实。
# --------分隔线--------
# 电影名称： 彗星来的那一夜
# 导演与演员： 导演:詹姆斯·沃德·布柯特JamesWardByrkit主演:艾米丽·芭尔多尼Em...2013/美国英国/科幻悬疑惊悚
# 电影评分： 8.5
# 评价人数： 461580人评价
# 电影总结： 小成本大魅力。
# --------分隔线--------
# 电影名称： 燃情岁月
# 导演与演员： 导演:爱德华·兹威克EdwardZwick主演:布拉德·皮特BradPitt/安东...1994/美国/剧情爱情战争西部
# 电影评分： 8.8
# 评价人数： 251153人评价
# 电影总结： 传奇，不是每个人都可以拥有。
# --------分隔线--------
# 电影名称： 战争之王
# 导演与演员： 导演:安德鲁·尼科尔AndrewNiccol主演:尼古拉斯·凯奇NicolasCage/...2005/法国德国美国/剧情犯罪
# 电影评分： 8.7
# 评价人数： 308336人评价
# 电影总结： 做一颗让别人需要你的棋子。
# --------分隔线--------
# 电影名称： 茶馆
# 导演与演员： 导演:谢添TianXie主演:于是之ShizhiYu/郑榕RongZhen/蓝天野T...1982/中国大陆/剧情历史
# 电影评分： 9.5
# 评价人数： 81388人评价
# 电影总结：
# --------分隔线--------
# 电影名称： 千钧一发
# 导演与演员： 导演:安德鲁·尼科尔AndrewNiccol主演:伊桑·霍克EthanHawke/乌玛...1997/美国/剧情科幻惊悚
# 电影评分： 8.8
# 评价人数： 235111人评价
# 电影总结： 一部能引人思考的科幻励志片。
# --------分隔线--------
# 电影名称： 谍影重重2
# 导演与演员： 导演:保罗·格林格拉斯PaulGreengrass主演:马特·达蒙MattDamon/...2004/美国德国/动作悬疑惊悚
# 电影评分： 8.7
# 评价人数： 306519人评价
# 电影总结： 谁说王家卫镜头很晃？
# --------分隔线--------
# 电影名称： 黑客帝国2：重装上阵
# 导演与演员： 导演:拉娜·沃卓斯基LanaWachowski/莉莉·沃卓斯基LillyWachowski...2003/美国/动作科幻
# 电影评分： 8.6
# 评价人数： 335788人评价
# 电影总结： 一个精彩的世界观正在缓缓建立。
# --------分隔线--------
# 电影名称： 海洋
# 导演与演员： 导演:雅克·贝汉JacquesPerrin/雅克·克鲁奥德JacquesCluzaud主演:...2009/法国瑞士西班牙美国阿联酋摩纳哥/纪录片
# 电影评分： 9.1
# 评价人数： 143696人评价
# 电影总结： 大海啊，不全是水。
# --------分隔线--------
# 电影名称： 崖上的波妞
# 导演与演员： 导演:宫崎骏HayaoMiyazaki主演:奈良柚莉爱YuriaNara/土井洋辉Hir...2008/日本/动画奇幻冒险
# 电影评分： 8.6
# 评价人数： 403177人评价
# 电影总结：
# --------分隔线--------
# 电影名称： 阿飞正传
# 导演与演员： 导演:王家卫KarWaiWong主演:张国荣LeslieCheung/张曼玉MaggieC...1990/中国香港/犯罪剧情爱情
# 电影评分： 8.5
# 评价人数： 432208人评价
# 电影总结： 王家卫是一种风格，张国荣是一个代表。
# --------分隔线--------
# 电影名称： 穿越时空的少女
# 导演与演员： 导演:细田守MamoruHosoda主演:仲里依纱RiisaNaka/石田卓也Takuya...2006/日本/剧情爱情科幻动画
# 电影评分： 8.6
# 评价人数： 337329人评价
# 电影总结： 爱上未来的你。
# --------分隔线--------
# 电影名称： 谍影重重
# 导演与演员： 导演:道格·里曼DougLiman主演:马特·达蒙MattDamon/弗兰卡·波坦...2002/美国德国捷克/动作悬疑惊悚
# 电影评分： 8.6
# 评价人数： 367301人评价
# 电影总结： 哗啦啦啦啦，天在下雨，哗啦啦啦啦，云在哭泣……找自己。
# --------分隔线--------
# 电影名称： 地球上的星星
# 导演与演员： 导演:阿米尔·汗AamirKhan主演:达席尔·萨法瑞DarsheelSafary/阿...2007/印度/剧情儿童家庭
# 电影评分： 8.9
# 评价人数： 179885人评价
# 电影总结： 天使保护事件始末。
# --------分隔线--------
# 电影名称： 背靠背，脸对脸
# 导演与演员： 导演:黄建新JianxinHuang/杨亚洲YazhouYang主演:牛振华ZhenhuaN...1994/中国大陆中国香港/剧情
# 电影评分： 9.5
# 评价人数： 84015人评价
# 电影总结：
# --------分隔线--------
# 电影名称： 完美陌生人
# 导演与演员： 导演:保罗·格诺维瑟PaoloGenovese主演:马可·贾利尼MarcoGiallini...2016/意大利/剧情喜剧
# 电影评分： 8.5
# 评价人数： 466556人评价
# 电影总结： 来啊，互相伤害啊！
# --------分隔线--------
# 电影名称： 香水
# 导演与演员： 导演:汤姆·提克威TomTykwer主演:本·卫肖BenWhishaw/艾伦·瑞克...2006/德国法国西班牙美国比利时/剧情犯罪奇幻
# 电影评分： 8.5
# 评价人数： 482165人评价
# 电影总结： 一个单凭体香达到高潮的男人。
# --------分隔线--------
# 电影名称： 再次出发之纽约遇见你
# 导演与演员： 导演:约翰·卡尼JohnCarney主演:凯拉·奈特莉KeiraKnightley/马克...2013/美国/喜剧爱情音乐
# 电影评分： 8.6
# 评价人数： 367992人评价
# 电影总结： 爱我就给我看你的播放列表。
# --------分隔线--------
# 电影名称： 我爱你
# 导演与演员： 导演:秋昌民Chang-minChoo主演:宋在河Jae-hoSong/李顺载Soon-jae...2011/韩国/剧情爱情
# 电影评分： 9.1
# 评价人数： 142224人评价
# 电影总结： 你要相信，这世上真的有爱存在，不管在什么年纪
# --------分隔线--------
# 电影名称： 小丑
# 导演与演员： 导演:托德·菲利普斯ToddPhillips主演:杰昆·菲尼克斯JoaquinPhoeni...2019/美国加拿大/剧情犯罪惊悚
# 电影评分： 8.7
# 评价人数： 856110人评价
# 电影总结：
# --------分隔线--------
# 电影名称： 朗读者
# 导演与演员： 导演:史蒂芬·戴德利StephenDaldry主演:凯特·温丝莱特KateWinslet...2008/美国德国/剧情爱情
# 电影评分： 8.6
# 评价人数： 408542人评价
# 电影总结： 当爱情跨越年龄的界限，它似乎能变得更久远一点，成为一种责任，一种水到渠成的相濡以沫。
# --------分隔线--------
# 电影名称： 爱乐之城
# 导演与演员： 导演:达米恩·查泽雷DamienChazelle主演:瑞恩·高斯林RyanGosling/...2016/美国/剧情爱情歌舞
# 电影评分： 8.4
# 评价人数： 721207人评价
# 电影总结：
# --------分隔线--------
# 电影名称： 驴得水
# 导演与演员： 导演:周申ShenZhou/刘露LuLiu主演:任素汐SuxiRen/大力DaLi...2016/中国大陆/剧情喜剧
# 电影评分： 8.3
# 评价人数： 798326人评价
# 电影总结： 过去的如果就让它过去了，未来只会越来越糟！
# --------分隔线--------
# 电影名称： 聚焦
# 导演与演员： 导演:托马斯·麦卡锡ThomasMcCarthy主演:马克·鲁弗洛MarkRuffalo/...2015/美国/剧情传记
# 电影评分： 8.8
# 评价人数： 242182人评价
# 电影总结： 新闻人的理性求真。
# --------分隔线--------
# 电影名称： 火星救援
# 导演与演员： 导演:雷德利·斯科特RidleyScott主演:马特·达蒙MattDamon/杰西卡...2015/英国美国匈牙利约旦/剧情科幻冒险
# 电影评分： 8.5
# 评价人数： 602968人评价
# 电影总结：
# --------分隔线--------
# 电影名称： 小萝莉的猴神大叔
# 导演与演员： 导演:卡比尔·汗KabirKhan主演:萨尔曼·汗SalmanKhan/哈莎莉·马...2015/印度/剧情喜剧动作
# 电影评分： 8.4
# 评价人数： 429652人评价
# 电影总结： 宝莱坞的萝莉与大叔。
# --------分隔线--------
# 电影名称： 浪潮
# 导演与演员： 导演:丹尼斯·甘塞尔DennisGansel主演:尤尔根·沃格尔JürgenVogel...2008/德国/剧情惊悚
# 电影评分： 8.7
# 评价人数： 237296人评价
# 电影总结： 世界离独裁只有五天。
# --------分隔线--------
# 电影名称： 猜火车
# 导演与演员： 导演:丹尼·博伊尔DannyBoyle主演:伊万·麦克格雷格EwanMcGregor/...1996/英国/剧情犯罪
# 电影评分： 8.6
# 评价人数： 373601人评价
# 电影总结： 不可猜的青春迷笛。
# --------分隔线--------
# 电影名称： 千年女优
# 导演与演员： 导演:今敏SatoshiKon主演:庄司美代子MiyokoShôji/小山茉美Mam...2001/日本/动画剧情爱情
# 电影评分： 8.8
# 评价人数： 203346人评价
# 电影总结： 爱情是一场没有尽头的虚幻追逐。
# --------分隔线--------
